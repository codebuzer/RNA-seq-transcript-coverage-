# %% [markdown]
# ## This notebook contains the code for Boruta gene selection analysis
# #### if u want to know more about boruta please follow this link https://www.researchgate.net/publication/220443685_Boruta_-_A_System_for_Feature_Selection

# %% [markdown]
# ## Libraries Required

# %%
import warnings
import scipy as sp
import numpy as np
import pandas as pd
from sklearn.metrics import *
import matplotlib.pyplot as plt
from scipy.stats import randint
from __future__ import print_function, division
from sklearn.preprocessing import label_binarize
from sklearn.exceptions import ConvergenceWarning
from sklearn.multiclass import OneVsRestClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV
from sklearn.utils import check_random_state, check_X_y
from sklearn.base import TransformerMixin, BaseEstimator
warnings.filterwarnings("ignore", category=ConvergenceWarning)
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import RandomizedSearchCV
  # Assuming you are using the Boruta library

# %% [markdown]
# ## Read the abundance Data

# %%
df = pd.read_csv('abundance.csv')

# %% [markdown]
# ## This is how our data looks like

# %%
df
# Out:
#             Unnamed: 0  IGIB113083612  IGIB113002257842  IGIB113003405741  \
# 0      ENSG00000000419       6.467632          6.076438          5.683727
# 1      ENSG00000000457       5.623925          5.899103          5.866506
# 2      ENSG00000000460       4.633771          4.973219          4.867171
# 3      ENSG00000000938      10.832606          9.355316         11.291813
# 4      ENSG00000000971       4.529797          4.356021          4.054426
# ...                ...            ...               ...               ...
# 17505  ENSG00000291336       4.689758          3.655313          4.079810
# 17506  ENSG00000291338       3.668090          4.382862          3.785763
# 17507  ENSG00000292246       4.711424          5.189790          4.291236
# 17508  ENSG00000292256       4.504034          3.628397          4.819180
# 17509  ENSG00000292277       5.095664          6.290188          4.648926
#
#        IGIB1130388376  IGIB1130493563  IGIB1130490942  IGIB113002277314  \
# 0            6.811358        6.247092        6.142734          6.689794
# 1            6.343263        5.953088        5.690140          5.413108
# 2            4.249772        4.745624        4.380331          4.518587
# 3           10.348202       11.474831       11.143710         10.281925
# 4            5.764041        4.428250        4.646614          3.927307
# ...               ...             ...             ...               ...
# 17505        4.829806        3.939064        4.250575          5.011823
# 17506        4.614524        3.184557        3.621223          4.018349
# 17507        6.526125        4.179311        4.530280          4.113246
# 17508        4.551845        4.398893        4.509124          4.989322
# 17509        4.954858        5.174722        4.523965          5.317822
#
#        IGIB113002356641  IGIB113002374331  ...  IGIB1130259871  \
# 0              6.255150          6.708819  ...        6.694202
# 1              6.388867          6.437203  ...        3.029895
# 2              4.519699          4.286728  ...        5.168628
# 3             10.995389         10.225057  ...        9.422564
# 4              4.865398          3.825975  ...        7.193971
# ...                 ...               ...  ...             ...
# 17505          4.597696          5.708802  ...        4.903466
# 17506          3.961234          3.973248  ...        2.715071
# 17507          5.064168          4.399511  ...        6.574159
# 17508          4.496130          4.428645  ...        5.721463
# 17509          5.086978          5.041272  ...        5.785872
#
#        IGIB113002393366  IGIB1130630558  IGIB1130927408  IGIB1130349380  \
# 0              7.901524        8.012131        6.277041        6.726043
# 1              7.261276        5.189570        6.216381        5.836147
# 2              7.824012        3.008087        5.219074        4.615122
# 3              9.727594        9.801387       10.701707        9.642007
# 4              9.959385        7.415074        6.312506        7.009848
# ...                 ...             ...             ...             ...
# 17505          5.898477        5.375463        5.431596        5.504055
# 17506          5.704757        2.715071        4.734596        5.282772
# 17507          9.482777        6.643534        5.070346        6.874143
# 17508          5.531927        2.680458        2.680458        3.934241
# 17509          5.557984        6.330864        6.206755        5.658364
#
#        IGIB113002297804  IGIB113002307585  IGIB113002393520  IGIB1130489912  \
# 0              6.754484          8.478701          7.480954        6.927056
# 1              6.007279          5.841475          6.698566        5.896934
# 2              4.285362          5.749757          5.931519        4.402074
# 3             12.127709          6.416470          9.838593       10.872446
# 4              4.504181          8.779507          7.661630        5.086159
# ...                 ...               ...               ...             ...
# 17505          4.174714          3.671268          5.656668        3.909011
# 17506          4.183960          4.537756          4.345707        3.915302
# 17507          5.211896          8.538606          8.540747        4.955177
# 17508          4.933003          4.090932          5.767498        4.499607
# 17509          5.467460          6.940705          6.438096        4.779403
#
#        IGIB113002190929
# 0              7.173671
# 1              6.383314
# 2              4.918354
# 3             11.114855
# 4              4.989686
# ...                 ...
# 17505          4.577528
# 17506          4.391036
# 17507          5.550013
# 17508          4.982629
# 17509          5.478778
#
# [17510 rows x 113 columns]

# %% [markdown]
#  ## Preprocessing step of the data so that we can make it compatible as an input for boruta

# %%
def preprocessing(df,cat,ref):

    """
    df ----> Gene Matrix, where columns are the sample ids and rows are the gene Id and its corresponding read counts.
    cat----> It contains the info of the samples whether it belongs to mild moderate or severe
    ref ----> reference gene data from gtf to gain the info of biotype.

    This function return 3 matrix {Protein coding, pseudogene, lncrna}
    """
    ref = pd.read_csv(ref)
    batch = pd.read_csv(cat)
    ref = ref[['Gene_id','Gene_biotype']]
    df = df.rename(columns = {'Unnamed: 0':'Gene_id'})
    df = ref.merge(df,on  = 'Gene_id', how = 'inner')
    protein_coding = df[df['Gene_biotype'] == 'protein_coding'].reset_index().drop(['index','Gene_biotype'],axis  =1)
    lncrna = df[df['Gene_biotype'] == 'lncRNA'].reset_index().drop(['index','Gene_biotype'],axis  =1)
    pseudogene = df[df['Gene_biotype'] == 'pseudogenes'].reset_index().drop(['index','Gene_biotype'],axis  =1)
    
    protein_coding = protein_coding.T
    col_pc = protein_coding.iloc[0,0:]
    protein_coding.columns = col_pc
    protein_coding = protein_coding.iloc[1:]
    protein_coding = protein_coding.reset_index().rename(columns = {'index':'Sample_ID'})
    protein_coding = batch.merge(protein_coding,on  = 'Sample_ID', how = 'inner')

    lncrna = lncrna.T
    col_ln = lncrna.iloc[0,0:]
    lncrna.columns = col_ln
    lncrna = lncrna.iloc[1:]
    lncrna = lncrna.reset_index().rename(columns = {'index':'Sample_ID'})
    lncrna = batch.merge(lncrna,on  = 'Sample_ID', how = 'inner')

    pseudogene = pseudogene.T
    col_ps = pseudogene.iloc[0,0:]
    pseudogene.columns = col_ps
    pseudogene = pseudogene.iloc[1:]
    pseudogene = pseudogene.reset_index().rename(columns = {'index':'Sample_ID'})
    pseudogene = batch.merge(pseudogene,on  = 'Sample_ID', how = 'inner')
    
    
    return protein_coding,lncrna,pseudogene

# %%
protein_coding,lncrna,pseudogene = preprocessing(df,'batch_category.csv','referencegenes.csv')

# %% [markdown]
# ## Initiate Boruta Pipelinie

# %%
class BorutaPy(BaseEstimator, TransformerMixin):

    def __init__(self, estimator, n_estimators=1000, perc=100, alpha=0.05,
                 two_step=True, max_iter=100, random_state=None, verbose=0,
                 early_stopping=False, n_iter_no_change=20):
        self.estimator = estimator
        self.n_estimators = n_estimators
        self.perc = perc
        self.alpha = alpha
        self.two_step = two_step
        self.max_iter = max_iter
        self.random_state = random_state
        self.verbose = verbose
        self.early_stopping = early_stopping
        self.n_iter_no_change = n_iter_no_change
        self.__version__ = '0.3'
        self._is_lightgbm = 'lightgbm' in str(type(self.estimator))

    def fit(self, X, y):
       

        return self._fit(X, y)

    def transform(self, X, weak=False, return_df=False):
       

        return self._transform(X, weak, return_df)

    def fit_transform(self, X, y, weak=False, return_df=False):
      

        self._fit(X, y)
        return self._transform(X, weak, return_df)

    def _validate_pandas_input(self, arg):
        try:
            return arg.values
        except AttributeError:
            raise ValueError(
                "input needs to be a numpy array or pandas data frame."
            )

    def _fit(self, X, y):
        # check input params
        self._check_params(X, y)

        if not isinstance(X, np.ndarray):
            X = self._validate_pandas_input(X) 
        if not isinstance(y, np.ndarray):
            y = self._validate_pandas_input(y)

        self.random_state = check_random_state(self.random_state)
        
        early_stopping = False
        if self.early_stopping:
            if self.n_iter_no_change >= self.max_iter:
                if self.verbose > 0:
                    print(
                        f"n_iter_no_change is bigger or equal to max_iter"
                        f"({self.n_iter_no_change} >= {self.max_iter}), "
                        f"early stopping will not be used."
                    )
            else:
                early_stopping = True
        
        # setup variables for Boruta
        n_sample, n_feat = X.shape
        _iter = 1
        # early stopping vars
        _same_iters = 1
        _last_dec_reg = None
        # holds the decision about each feature:
        # 0  - default state = tentative in original code
        # 1  - accepted in original code
        # -1 - rejected in original code
        dec_reg = np.zeros(n_feat, dtype=int)
        # counts how many times a given feature was more important than
        # the best of the shadow features
        hit_reg = np.zeros(n_feat, dtype=int)
        # these record the history of the iterations
        imp_history = np.zeros(n_feat, dtype=float)
        sha_max_history = []

        # set n_estimators
        if self.n_estimators != 'auto':
            self.estimator.set_params(n_estimators=self.n_estimators)

        # main feature selection loop
        while np.any(dec_reg == 0) and _iter < self.max_iter:
            # find optimal number of trees and depth
            if self.n_estimators == 'auto':
                # number of features that aren't rejected
                not_rejected = np.where(dec_reg >= 0)[0].shape[0]
                n_tree = self._get_tree_num(not_rejected)
                self.estimator.set_params(n_estimators=n_tree)

            # make sure we start with a new tree in each iteration
            if self._is_lightgbm:
                self.estimator.set_params(random_state=self.random_state.randint(0, 10000))
            else:
                self.estimator.set_params(random_state=self.random_state)

            # add shadow attributes, shuffle them and train estimator, get imps
            cur_imp = self._add_shadows_get_imps(X, y, dec_reg)

            # get the threshold of shadow importances we will use for rejection
            imp_sha_max = np.percentile(cur_imp[1], self.perc)

            # record importance history
            sha_max_history.append(imp_sha_max)
            imp_history = np.vstack((imp_history, cur_imp[0]))

            # register which feature is more imp than the max of shadows
            hit_reg = self._assign_hits(hit_reg, cur_imp, imp_sha_max)

            # based on hit_reg we check if a feature is doing better than
            # expected by chance
            dec_reg = self._do_tests(dec_reg, hit_reg, _iter)

            # print out confirmed features
            if self.verbose > 0 and _iter < self.max_iter:
                self._print_results(dec_reg, _iter, 0)
            if _iter < self.max_iter:
                _iter += 1
                
            # early stopping
            if early_stopping:
                if _last_dec_reg is not None and (_last_dec_reg == dec_reg).all():
                    _same_iters += 1
                    if self.verbose > 0:
                        print(
                            f"Early stopping: {_same_iters} out "
                            f"of {self.n_iter_no_change}"
                        )
                else:
                    _same_iters = 1
                    _last_dec_reg = dec_reg.copy()
                if _same_iters > self.n_iter_no_change:
                    break

        # we automatically apply R package's rough fix for tentative ones
        confirmed = np.where(dec_reg == 1)[0]
        tentative = np.where(dec_reg == 0)[0]
        # ignore the first row of zeros
        tentative_median = np.median(imp_history[1:, tentative], axis=0)
        # which tentative to keep
        tentative_confirmed = np.where(tentative_median
                                       > np.median(sha_max_history))[0]
        tentative = tentative[tentative_confirmed]

        # basic result variables
        self.n_features_ = confirmed.shape[0]
        self.support_ = np.zeros(n_feat, dtype=bool)
        self.support_[confirmed] = 1
        self.support_weak_ = np.zeros(n_feat, dtype=bool)
        self.support_weak_[tentative] = 1

        # ranking, confirmed variables are rank 1
        self.ranking_ = np.ones(n_feat, dtype=int)
        # tentative variables are rank 2
        self.ranking_[tentative] = 2
        # selected = confirmed and tentative
        selected = np.hstack((confirmed, tentative))
        # all rejected features are sorted by importance history
        not_selected = np.setdiff1d(np.arange(n_feat), selected)
        # large importance values should rank higher = lower ranks -> *(-1)
        imp_history_rejected = imp_history[1:, not_selected] * -1

        # update rank for not_selected features
        if not_selected.shape[0] > 0:
                # calculate ranks in each iteration, then median of ranks across feats
                iter_ranks = self._nanrankdata(imp_history_rejected, axis=1)
                rank_medians = np.nanmedian(iter_ranks, axis=0)
                ranks = self._nanrankdata(rank_medians, axis=0)

                # set smallest rank to 3 if there are tentative feats
                if tentative.shape[0] > 0:
                    ranks = ranks - np.min(ranks) + 3
                else:
                    # and 2 otherwise
                    ranks = ranks - np.min(ranks) + 2
                self.ranking_[not_selected] = ranks
        else:
            # all are selected, thus we set feature supports to True
            self.support_ = np.ones(n_feat, dtype=bool)

        self.importance_history_ = imp_history

        # notify user
        if self.verbose > 0:
            self._print_results(dec_reg, _iter, 1)
        return self

    def _transform(self, X, weak=False, return_df=False):
        # sanity check
        try:
            self.ranking_
        except AttributeError:
            raise ValueError('You need to call the fit(X, y) method first.')

        if weak:
            indices = self.support_ + self.support_weak_
        else:
            indices = self.support_

        if return_df:
            X = X.iloc[:, indices]
        else:
            X = X[:, indices]
        return X

    def _get_tree_num(self, n_feat):
        depth = None
        try:
            depth = self.estimator.get_params()['max_depth']
        except KeyError:
            warnings.warn(
                "The estimator does not have a max_depth property, as a result "
                " the number of trees to use cannot be estimated automatically."
            )
        if depth == None:
            depth = 10
        # how many times a feature should be considered on average
        f_repr = 100
        # n_feat * 2 because the training matrix is extended with n shadow features
        multi = ((n_feat * 2) / (np.sqrt(n_feat * 2) * depth))
        n_estimators = int(multi * f_repr)
        return n_estimators

    def _get_imp(self, X, y):
        try:
            self.estimator.fit(X, y)
        except Exception as e:
            raise ValueError('Please check your X and y variable. The provided '
                             'estimator cannot be fitted to your data.\n' + str(e))
        try:
            imp = self.estimator.feature_importances_
        except Exception:
            raise ValueError('Only methods with feature_importance_ attribute '
                             'are currently supported in BorutaPy.')
        return imp

    def _get_shuffle(self, seq):
        self.random_state.shuffle(seq)
        return seq

    def _add_shadows_get_imps(self, X, y, dec_reg):
        # find features that are tentative still
        x_cur_ind = np.where(dec_reg >= 0)[0]
        x_cur = np.copy(X[:, x_cur_ind])
        x_cur_w = x_cur.shape[1]
        # deep copy the matrix for the shadow matrix
        x_sha = np.copy(x_cur)
        # make sure there's at least 5 columns in the shadow matrix for
        while (x_sha.shape[1] < 5):
            x_sha = np.hstack((x_sha, x_sha))
        # shuffle xSha
        x_sha = np.apply_along_axis(self._get_shuffle, 0, x_sha)
        # get importance of the merged matrix
        imp = self._get_imp(np.hstack((x_cur, x_sha)), y)
        # separate importances of real and shadow features
        imp_sha = imp[x_cur_w:]
        imp_real = np.zeros(X.shape[1])
        imp_real[:] = np.nan
        imp_real[x_cur_ind] = imp[:x_cur_w]
        return imp_real, imp_sha

    def _assign_hits(self, hit_reg, cur_imp, imp_sha_max):
        # register hits for features that did better than the best of shadows
        cur_imp_no_nan = cur_imp[0]
        cur_imp_no_nan[np.isnan(cur_imp_no_nan)] = 0
        hits = np.where(cur_imp_no_nan > imp_sha_max)[0]
        hit_reg[hits] += 1
        return hit_reg

    def _do_tests(self, dec_reg, hit_reg, _iter):
        active_features = np.where(dec_reg >= 0)[0]
        hits = hit_reg[active_features]
        # get uncorrected p values based on hit_reg
        to_accept_ps = sp.stats.binom.sf(hits - 1, _iter, .5).flatten()
        to_reject_ps = sp.stats.binom.cdf(hits, _iter, .5).flatten()

        if self.two_step:
            # two step multicor process
            # first we correct for testing several features in each round using FDR
            to_accept = self._fdrcorrection(to_accept_ps, alpha=self.alpha)[0]
            to_reject = self._fdrcorrection(to_reject_ps, alpha=self.alpha)[0]

            # second we correct for testing the same feature over and over again
            # using bonferroni
            to_accept2 = to_accept_ps <= self.alpha / float(_iter)
            to_reject2 = to_reject_ps <= self.alpha / float(_iter)

            # combine the two multi corrections, and get indexes
            to_accept *= to_accept2
            to_reject *= to_reject2
        else:
            # as in th original Boruta, we simply do bonferroni correction
            # with the total n_feat in each iteration
            to_accept = to_accept_ps <= self.alpha / float(len(dec_reg))
            to_reject = to_reject_ps <= self.alpha / float(len(dec_reg))

        # find features which are 0 and have been rejected or accepted
        to_accept = np.where((dec_reg[active_features] == 0) * to_accept)[0]
        to_reject = np.where((dec_reg[active_features] == 0) * to_reject)[0]

        # updating dec_reg
        dec_reg[active_features[to_accept]] = 1
        dec_reg[active_features[to_reject]] = -1
        return dec_reg

    def _fdrcorrection(self, pvals, alpha=0.05):
       
        pvals = np.asarray(pvals)
        pvals_sortind = np.argsort(pvals)
        pvals_sorted = np.take(pvals, pvals_sortind)
        nobs = len(pvals_sorted)
        ecdffactor = np.arange(1, nobs + 1) / float(nobs)

        reject = pvals_sorted <= ecdffactor * alpha
        if reject.any():
            rejectmax = max(np.nonzero(reject)[0])
            reject[:rejectmax] = True

        pvals_corrected_raw = pvals_sorted / ecdffactor
        pvals_corrected = np.minimum.accumulate(pvals_corrected_raw[::-1])[::-1]
        pvals_corrected[pvals_corrected > 1] = 1
        # reorder p-values and rejection mask to original order of pvals
        pvals_corrected_ = np.empty_like(pvals_corrected)
        pvals_corrected_[pvals_sortind] = pvals_corrected
        reject_ = np.empty_like(reject)
        reject_[pvals_sortind] = reject
        return reject_, pvals_corrected_

    def _nanrankdata(self, X, axis=1):
        """
        Replaces bottleneck's nanrankdata with scipy and numpy alternative.
        """
        ranks = sp.stats.mstats.rankdata(X, axis=axis)
        ranks[np.isnan(X)] = np.nan
        return ranks

    def _check_params(self, X, y):
        """
        Check hyperparameters as well as X and y before proceeding with fit.
        """
        # check X and y are consistent len, X is Array and y is column
        X, y = check_X_y(X, y)
        if self.perc <= 0 or self.perc > 100:
            raise ValueError('The percentile should be between 0 and 100.')

        if self.alpha <= 0 or self.alpha > 1:
            raise ValueError('Alpha should be between 0 and 1.')

    def _print_results(self, dec_reg, _iter, flag):
        n_iter = str(_iter) + ' / ' + str(self.max_iter)
        n_confirmed = np.where(dec_reg == 1)[0].shape[0]
        n_rejected = np.where(dec_reg == -1)[0].shape[0]
        cols = ['Iteration: ', 'Confirmed: ', 'Tentative: ', 'Rejected: ']

        # still in feature selection
        if flag == 0:
            n_tentative = np.where(dec_reg == 0)[0].shape[0]
            content = map(str, [n_iter, n_confirmed, n_tentative, n_rejected])
            if self.verbose == 1:
                output = cols[0] + n_iter
            elif self.verbose > 1:
                output = '\n'.join([x[0] + '\t' + x[1] for x in zip(cols, content)])

        # Boruta finished running and tentatives have been filtered
        else:
            n_tentative = np.sum(self.support_weak_)
            n_rejected = np.sum(~(self.support_|self.support_weak_))
            content = map(str, [n_iter, n_confirmed, n_tentative, n_rejected])
            result = '\n'.join([x[0] + '\t' + x[1] for x in zip(cols, content)])
            output = "\n\nBorutaPy finished running.\n\n" + result
        print(output)

# %%
def HyperParamTuning(df):
    # Separate features and target
    feat = df.drop(['Sample_ID', 'category'], axis=1)
    target = df['category']
    target_numeric = target.astype('category').cat.codes
    
    # Create a RandomForestClassifier
    rf = RandomForestClassifier(class_weight='balanced', random_state=42)

    # Use RandomizedSearchCV for hyperparameter tuning
    param_dist = {
        'n_estimators': [50, 100, 150],
        'max_depth': [None, 10, 20, 30],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4]
    }
    
    random_search = RandomizedSearchCV(
        rf, param_distributions=param_dist, n_iter=10, cv=5, scoring='accuracy', random_state=42
    )
    
    print('started fitting random search')
    random_search.fit(feat, target_numeric)

    # Get the best estimator from the search
    best_rf = random_search.best_estimator_
    print('Done fitting random search')
   
    return best_rf,feat,target_numeric

# %%
best_rf_pc,feat_pc,target_numeric_pc = HyperParamTuning(protein_coding)
# Out:
# started fitting random search
# Done fitting random search

# %%
best_rf_ln,feat_ln,target_numeric_ln = HyperParamTuning(lncrna)
# Out:
# started fitting random search
# Done fitting random search

# %%
best_rf_ps,feat_ps,target_numeric_ps = HyperParamTuning(pseudogene)

# %%
def GeneSelection(model,feat,target):
    boruta_selector = BorutaPy(model, n_estimators='auto', verbose=2, random_state=42,max_iter = 1000)
    boruta_selector.fit(feat.values, target.values)
    selected_features = feat.columns[boruta_selector.support_].tolist()

    return selected_features

# %%
selected_features_pc = GeneSelection(best_rf_pc,feat_pc,target_numeric_pc)
# Out:
# Iteration: 	1 / 1000
# Confirmed: 	0
# Tentative: 	13374
# Rejected: 	0
# Iteration: 	2 / 1000
# Confirmed: 	0
# Tentative: 	13374
# Rejected: 	0
# Iteration: 	3 / 1000
# Confirmed: 	0
# Tentative: 	13374
# Rejected: 	0
# Iteration: 	4 / 1000
# Confirmed: 	0
# Tentative: 	13374
# Rejected: 	0
# Iteration: 	5 / 1000
# Confirmed: 	0
# Tentative: 	13374
# Rejected: 	0
# Iteration: 	6 / 1000
# Confirmed: 	0
# Tentative: 	13374
# Rejected: 	0
# Iteration: 	7 / 1000
# Confirmed: 	0
# Tentative: 	13374
# Rejected: 	0
# Iteration: 	8 / 1000
# Confirmed: 	0
# Tentative: 	384
# Rejected: 	12990
# Iteration: 	9 / 1000
# Confirmed: 	0
# Tentative: 	384
# Rejected: 	12990
# Iteration: 	10 / 1000
# Confirmed: 	10
# Tentative: 	374
# Rejected: 	12990
# Iteration: 	11 / 1000
# Confirmed: 	10
# Tentative: 	374
# Rejected: 	12990
# Iteration: 	12 / 1000
# Confirmed: 	10
# Tentative: 	300
# Rejected: 	13064
# Iteration: 	13 / 1000
# Confirmed: 	21
# Tentative: 	289
# Rejected: 	13064
# Iteration: 	14 / 1000
# Confirmed: 	21
# Tentative: 	289
# Rejected: 	13064
# Iteration: 	15 / 1000
# Confirmed: 	21
# Tentative: 	289
# Rejected: 	13064
# Iteration: 	16 / 1000
# Confirmed: 	24
# Tentative: 	256
# Rejected: 	13094
# Iteration: 	17 / 1000
# Confirmed: 	24
# Tentative: 	256
# Rejected: 	13094
# Iteration: 	18 / 1000
# Confirmed: 	24
# Tentative: 	256
# Rejected: 	13094
# Iteration: 	19 / 1000
# Confirmed: 	29
# Tentative: 	233
# Rejected: 	13112
# Iteration: 	20 / 1000
# Confirmed: 	29
# Tentative: 	233
# Rejected: 	13112
# Iteration: 	21 / 1000
# Confirmed: 	29
# Tentative: 	233
# Rejected: 	13112
# Iteration: 	22 / 1000
# Confirmed: 	33
# Tentative: 	229
# Rejected: 	13112
# Iteration: 	23 / 1000
# Confirmed: 	33
# Tentative: 	222
# Rejected: 	13119
# Iteration: 	24 / 1000
# Confirmed: 	33
# Tentative: 	222
# Rejected: 	13119
# Iteration: 	25 / 1000
# Confirmed: 	33
# Tentative: 	222
# Rejected: 	13119
# Iteration: 	26 / 1000
# Confirmed: 	33
# Tentative: 	214
# Rejected: 	13127
# Iteration: 	27 / 1000
# Confirmed: 	33
# Tentative: 	214
# Rejected: 	13127
# Iteration: 	28 / 1000
# Confirmed: 	33
# Tentative: 	214
# Rejected: 	13127
# Iteration: 	29 / 1000
# Confirmed: 	34
# Tentative: 	204
# Rejected: 	13136
# Iteration: 	30 / 1000
# Confirmed: 	34
# Tentative: 	204
# Rejected: 	13136
# Iteration: 	31 / 1000
# Confirmed: 	34
# Tentative: 	204
# Rejected: 	13136
# Iteration: 	32 / 1000
# Confirmed: 	34
# Tentative: 	196
# Rejected: 	13144
# Iteration: 	33 / 1000
# Confirmed: 	34
# Tentative: 	196
# Rejected: 	13144
# Iteration: 	34 / 1000
# Confirmed: 	39
# Tentative: 	191
# Rejected: 	13144
# Iteration: 	35 / 1000
# Confirmed: 	39
# Tentative: 	191
# Rejected: 	13144
# Iteration: 	36 / 1000
# Confirmed: 	39
# Tentative: 	191
# Rejected: 	13144
# Iteration: 	37 / 1000
# Confirmed: 	40
# Tentative: 	190
# Rejected: 	13144
# Iteration: 	38 / 1000
# Confirmed: 	40
# Tentative: 	188
# Rejected: 	13146
# Iteration: 	39 / 1000
# Confirmed: 	40
# Tentative: 	188
# Rejected: 	13146
# Iteration: 	40 / 1000
# Confirmed: 	40
# Tentative: 	181
# Rejected: 	13153
# Iteration: 	41 / 1000
# Confirmed: 	40
# Tentative: 	181
# Rejected: 	13153
# Iteration: 	42 / 1000
# Confirmed: 	40
# Tentative: 	181
# Rejected: 	13153
# Iteration: 	43 / 1000
# Confirmed: 	43
# Tentative: 	178
# Rejected: 	13153
# Iteration: 	44 / 1000
# Confirmed: 	43
# Tentative: 	178
# Rejected: 	13153
# Iteration: 	45 / 1000
# Confirmed: 	43
# Tentative: 	178
# Rejected: 	13153
# Iteration: 	46 / 1000
# Confirmed: 	44
# Tentative: 	177
# Rejected: 	13153
# Iteration: 	47 / 1000
# Confirmed: 	44
# Tentative: 	177
# Rejected: 	13153
# Iteration: 	48 / 1000
# Confirmed: 	44
# Tentative: 	175
# Rejected: 	13155
# Iteration: 	49 / 1000
# Confirmed: 	44
# Tentative: 	175
# Rejected: 	13155
# Iteration: 	50 / 1000
# Confirmed: 	44
# Tentative: 	173
# Rejected: 	13157
# Iteration: 	51 / 1000
# Confirmed: 	44
# Tentative: 	173
# Rejected: 	13157
# Iteration: 	52 / 1000
# Confirmed: 	44
# Tentative: 	173
# Rejected: 	13157
# Iteration: 	53 / 1000
# Confirmed: 	44
# Tentative: 	173
# Rejected: 	13157
# Iteration: 	54 / 1000
# Confirmed: 	45
# Tentative: 	169
# Rejected: 	13160
# Iteration: 	55 / 1000
# Confirmed: 	45
# Tentative: 	169
# Rejected: 	13160
# Iteration: 	56 / 1000
# Confirmed: 	45
# Tentative: 	169
# Rejected: 	13160
# Iteration: 	57 / 1000
# Confirmed: 	45
# Tentative: 	169
# Rejected: 	13160
# Iteration: 	58 / 1000
# Confirmed: 	45
# Tentative: 	168
# Rejected: 	13161
# Iteration: 	59 / 1000
# Confirmed: 	45
# Tentative: 	168
# Rejected: 	13161
# Iteration: 	60 / 1000
# Confirmed: 	45
# Tentative: 	167
# Rejected: 	13162
# Iteration: 	61 / 1000
# Confirmed: 	45
# Tentative: 	167
# Rejected: 	13162
# Iteration: 	62 / 1000
# Confirmed: 	49
# Tentative: 	163
# Rejected: 	13162
# Iteration: 	63 / 1000
# Confirmed: 	49
# Tentative: 	162
# Rejected: 	13163
# Iteration: 	64 / 1000
# Confirmed: 	49
# Tentative: 	162
# Rejected: 	13163
# Iteration: 	65 / 1000
# Confirmed: 	50
# Tentative: 	158
# Rejected: 	13166
# Iteration: 	66 / 1000
# Confirmed: 	50
# Tentative: 	158
# Rejected: 	13166
# Iteration: 	67 / 1000
# Confirmed: 	50
# Tentative: 	151
# Rejected: 	13173
# Iteration: 	68 / 1000
# Confirmed: 	50
# Tentative: 	151
# Rejected: 	13173
# Iteration: 	69 / 1000
# Confirmed: 	50
# Tentative: 	151
# Rejected: 	13173
# Iteration: 	70 / 1000
# Confirmed: 	50
# Tentative: 	151
# Rejected: 	13173
# Iteration: 	71 / 1000
# Confirmed: 	50
# Tentative: 	151
# Rejected: 	13173
# Iteration: 	72 / 1000
# Confirmed: 	51
# Tentative: 	147
# Rejected: 	13176
# Iteration: 	73 / 1000
# Confirmed: 	51
# Tentative: 	147
# Rejected: 	13176
# Iteration: 	74 / 1000
# Confirmed: 	51
# Tentative: 	147
# Rejected: 	13176
# Iteration: 	75 / 1000
# Confirmed: 	52
# Tentative: 	146
# Rejected: 	13176
# Iteration: 	76 / 1000
# Confirmed: 	52
# Tentative: 	146
# Rejected: 	13176
# Iteration: 	77 / 1000
# Confirmed: 	53
# Tentative: 	145
# Rejected: 	13176
# Iteration: 	78 / 1000
# Confirmed: 	53
# Tentative: 	145
# Rejected: 	13176
# Iteration: 	79 / 1000
# Confirmed: 	53
# Tentative: 	145
# Rejected: 	13176
# Iteration: 	80 / 1000
# Confirmed: 	54
# Tentative: 	144
# Rejected: 	13176
# Iteration: 	81 / 1000
# Confirmed: 	54
# Tentative: 	144
# Rejected: 	13176
# Iteration: 	82 / 1000
# Confirmed: 	54
# Tentative: 	144
# Rejected: 	13176
# Iteration: 	83 / 1000
# Confirmed: 	55
# Tentative: 	142
# Rejected: 	13177
# Iteration: 	84 / 1000
# Confirmed: 	55
# Tentative: 	142
# Rejected: 	13177
# Iteration: 	85 / 1000
# Confirmed: 	55
# Tentative: 	142
# Rejected: 	13177
# Iteration: 	86 / 1000
# Confirmed: 	55
# Tentative: 	142
# Rejected: 	13177
# Iteration: 	87 / 1000
# Confirmed: 	55
# Tentative: 	142
# Rejected: 	13177
# Iteration: 	88 / 1000
# Confirmed: 	55
# Tentative: 	140
# Rejected: 	13179
# Iteration: 	89 / 1000
# Confirmed: 	55
# Tentative: 	140
# Rejected: 	13179
# Iteration: 	90 / 1000
# Confirmed: 	58
# Tentative: 	133
# Rejected: 	13183
# Iteration: 	91 / 1000
# Confirmed: 	58
# Tentative: 	133
# Rejected: 	13183
# Iteration: 	92 / 1000
# Confirmed: 	58
# Tentative: 	133
# Rejected: 	13183
# Iteration: 	93 / 1000
# Confirmed: 	60
# Tentative: 	131
# Rejected: 	13183
# Iteration: 	94 / 1000
# Confirmed: 	60
# Tentative: 	131
# Rejected: 	13183
# Iteration: 	95 / 1000
# Confirmed: 	62
# Tentative: 	129
# Rejected: 	13183
# Iteration: 	96 / 1000
# Confirmed: 	62
# Tentative: 	129
# Rejected: 	13183
# Iteration: 	97 / 1000
# Confirmed: 	62
# Tentative: 	129
# Rejected: 	13183
# Iteration: 	98 / 1000
# Confirmed: 	62
# Tentative: 	129
# Rejected: 	13183
# Iteration: 	99 / 1000
# Confirmed: 	62
# Tentative: 	129
# Rejected: 	13183
# Iteration: 	100 / 1000
# Confirmed: 	63
# Tentative: 	127
# Rejected: 	13184
# Iteration: 	101 / 1000
# Confirmed: 	63
# Tentative: 	127
# Rejected: 	13184
# Iteration: 	102 / 1000
# Confirmed: 	63
# Tentative: 	127
# Rejected: 	13184
# Iteration: 	103 / 1000
# Confirmed: 	63
# Tentative: 	127
# Rejected: 	13184
# Iteration: 	104 / 1000
# Confirmed: 	63
# Tentative: 	127
# Rejected: 	13184
# Iteration: 	105 / 1000
# Confirmed: 	64
# Tentative: 	126
# Rejected: 	13184
# Iteration: 	106 / 1000
# Confirmed: 	64
# Tentative: 	126
# Rejected: 	13184
# Iteration: 	107 / 1000
# Confirmed: 	66
# Tentative: 	123
# Rejected: 	13185
# Iteration: 	108 / 1000
# Confirmed: 	66
# Tentative: 	123
# Rejected: 	13185
# Iteration: 	109 / 1000
# Confirmed: 	66
# Tentative: 	123
# Rejected: 	13185
# Iteration: 	110 / 1000
# Confirmed: 	66
# Tentative: 	122
# Rejected: 	13186
# Iteration: 	111 / 1000
# Confirmed: 	66
# Tentative: 	122
# Rejected: 	13186
# Iteration: 	112 / 1000
# Confirmed: 	66
# Tentative: 	120
# Rejected: 	13188
# Iteration: 	113 / 1000
# Confirmed: 	66
# Tentative: 	120
# Rejected: 	13188
# Iteration: 	114 / 1000
# Confirmed: 	66
# Tentative: 	120
# Rejected: 	13188
# Iteration: 	115 / 1000
# Confirmed: 	67
# Tentative: 	118
# Rejected: 	13189
# Iteration: 	116 / 1000
# Confirmed: 	67
# Tentative: 	118
# Rejected: 	13189
# Iteration: 	117 / 1000
# Confirmed: 	68
# Tentative: 	117
# Rejected: 	13189
# Iteration: 	118 / 1000
# Confirmed: 	68
# Tentative: 	117
# Rejected: 	13189
# Iteration: 	119 / 1000
# Confirmed: 	68
# Tentative: 	117
# Rejected: 	13189
# Iteration: 	120 / 1000
# Confirmed: 	68
# Tentative: 	117
# Rejected: 	13189
# Iteration: 	121 / 1000
# Confirmed: 	68
# Tentative: 	117
# Rejected: 	13189
# Iteration: 	122 / 1000
# Confirmed: 	70
# Tentative: 	115
# Rejected: 	13189
# Iteration: 	123 / 1000
# Confirmed: 	70
# Tentative: 	115
# Rejected: 	13189
# Iteration: 	124 / 1000
# Confirmed: 	70
# Tentative: 	115
# Rejected: 	13189
# Iteration: 	125 / 1000
# Confirmed: 	70
# Tentative: 	115
# Rejected: 	13189
# Iteration: 	126 / 1000
# Confirmed: 	70
# Tentative: 	115
# Rejected: 	13189
# Iteration: 	127 / 1000
# Confirmed: 	71
# Tentative: 	114
# Rejected: 	13189
# Iteration: 	128 / 1000
# Confirmed: 	71
# Tentative: 	113
# Rejected: 	13190
# Iteration: 	129 / 1000
# Confirmed: 	71
# Tentative: 	113
# Rejected: 	13190
# Iteration: 	130 / 1000
# Confirmed: 	71
# Tentative: 	113
# Rejected: 	13190
# Iteration: 	131 / 1000
# Confirmed: 	71
# Tentative: 	113
# Rejected: 	13190
# Iteration: 	132 / 1000
# Confirmed: 	71
# Tentative: 	113
# Rejected: 	13190
# Iteration: 	133 / 1000
# Confirmed: 	71
# Tentative: 	113
# Rejected: 	13190
# Iteration: 	134 / 1000
# Confirmed: 	73
# Tentative: 	111
# Rejected: 	13190
# Iteration: 	135 / 1000
# Confirmed: 	73
# Tentative: 	111
# Rejected: 	13190
# Iteration: 	136 / 1000
# Confirmed: 	73
# Tentative: 	111
# Rejected: 	13190
# Iteration: 	137 / 1000
# Confirmed: 	74
# Tentative: 	110
# Rejected: 	13190
# Iteration: 	138 / 1000
# Confirmed: 	74
# Tentative: 	110
# Rejected: 	13190
# Iteration: 	139 / 1000
# Confirmed: 	76
# Tentative: 	107
# Rejected: 	13191
# Iteration: 	140 / 1000
# Confirmed: 	76
# Tentative: 	107
# Rejected: 	13191
# Iteration: 	141 / 1000
# Confirmed: 	76
# Tentative: 	105
# Rejected: 	13193
# Iteration: 	142 / 1000
# Confirmed: 	76
# Tentative: 	105
# Rejected: 	13193
# Iteration: 	143 / 1000
# Confirmed: 	76
# Tentative: 	105
# Rejected: 	13193
# Iteration: 	144 / 1000
# Confirmed: 	78
# Tentative: 	103
# Rejected: 	13193
# Iteration: 	145 / 1000
# Confirmed: 	78
# Tentative: 	103
# Rejected: 	13193
# Iteration: 	146 / 1000
# Confirmed: 	78
# Tentative: 	103
# Rejected: 	13193
# Iteration: 	147 / 1000
# Confirmed: 	78
# Tentative: 	103
# Rejected: 	13193
# Iteration: 	148 / 1000
# Confirmed: 	78
# Tentative: 	103
# Rejected: 	13193
# Iteration: 	149 / 1000
# Confirmed: 	78
# Tentative: 	103
# Rejected: 	13193
# Iteration: 	150 / 1000
# Confirmed: 	78
# Tentative: 	103
# Rejected: 	13193
# Iteration: 	151 / 1000
# Confirmed: 	79
# Tentative: 	100
# Rejected: 	13195
# Iteration: 	152 / 1000
# Confirmed: 	79
# Tentative: 	100
# Rejected: 	13195
# Iteration: 	153 / 1000
# Confirmed: 	79
# Tentative: 	100
# Rejected: 	13195
# Iteration: 	154 / 1000
# Confirmed: 	79
# Tentative: 	100
# Rejected: 	13195
# Iteration: 	155 / 1000
# Confirmed: 	79
# Tentative: 	100
# Rejected: 	13195
# Iteration: 	156 / 1000
# Confirmed: 	80
# Tentative: 	99
# Rejected: 	13195
# Iteration: 	157 / 1000
# Confirmed: 	80
# Tentative: 	99
# Rejected: 	13195
# Iteration: 	158 / 1000
# Confirmed: 	80
# Tentative: 	98
# Rejected: 	13196
# Iteration: 	159 / 1000
# Confirmed: 	80
# Tentative: 	98
# Rejected: 	13196
# Iteration: 	160 / 1000
# Confirmed: 	80
# Tentative: 	98
# Rejected: 	13196
# Iteration: 	161 / 1000
# Confirmed: 	80
# Tentative: 	97
# Rejected: 	13197
# Iteration: 	162 / 1000
# Confirmed: 	80
# Tentative: 	97
# Rejected: 	13197
# Iteration: 	163 / 1000
# Confirmed: 	81
# Tentative: 	95
# Rejected: 	13198
# Iteration: 	164 / 1000
# Confirmed: 	81
# Tentative: 	95
# Rejected: 	13198
# Iteration: 	165 / 1000
# Confirmed: 	81
# Tentative: 	95
# Rejected: 	13198
# Iteration: 	166 / 1000
# Confirmed: 	81
# Tentative: 	95
# Rejected: 	13198
# Iteration: 	167 / 1000
# Confirmed: 	81
# Tentative: 	95
# Rejected: 	13198
# Iteration: 	168 / 1000
# Confirmed: 	81
# Tentative: 	93
# Rejected: 	13200
# Iteration: 	169 / 1000
# Confirmed: 	81
# Tentative: 	93
# Rejected: 	13200
# Iteration: 	170 / 1000
# Confirmed: 	82
# Tentative: 	92
# Rejected: 	13200
# Iteration: 	171 / 1000
# Confirmed: 	82
# Tentative: 	92
# Rejected: 	13200
# Iteration: 	172 / 1000
# Confirmed: 	83
# Tentative: 	91
# Rejected: 	13200
# Iteration: 	173 / 1000
# Confirmed: 	83
# Tentative: 	91
# Rejected: 	13200
# Iteration: 	174 / 1000
# Confirmed: 	83
# Tentative: 	91
# Rejected: 	13200
# Iteration: 	175 / 1000
# Confirmed: 	84
# Tentative: 	90
# Rejected: 	13200
# Iteration: 	176 / 1000
# Confirmed: 	84
# Tentative: 	90
# Rejected: 	13200
# Iteration: 	177 / 1000
# Confirmed: 	84
# Tentative: 	90
# Rejected: 	13200
# Iteration: 	178 / 1000
# Confirmed: 	84
# Tentative: 	90
# Rejected: 	13200
# Iteration: 	179 / 1000
# Confirmed: 	84
# Tentative: 	89
# Rejected: 	13201
# Iteration: 	180 / 1000
# Confirmed: 	84
# Tentative: 	89
# Rejected: 	13201
# Iteration: 	181 / 1000
# Confirmed: 	84
# Tentative: 	89
# Rejected: 	13201
# Iteration: 	182 / 1000
# Confirmed: 	84
# Tentative: 	88
# Rejected: 	13202
# Iteration: 	183 / 1000
# Confirmed: 	84
# Tentative: 	88
# Rejected: 	13202
# Iteration: 	184 / 1000
# Confirmed: 	84
# Tentative: 	87
# Rejected: 	13203
# Iteration: 	185 / 1000
# Confirmed: 	84
# Tentative: 	87
# Rejected: 	13203
# Iteration: 	186 / 1000
# Confirmed: 	84
# Tentative: 	87
# Rejected: 	13203
# Iteration: 	187 / 1000
# Confirmed: 	84
# Tentative: 	87
# Rejected: 	13203
# Iteration: 	188 / 1000
# Confirmed: 	84
# Tentative: 	87
# Rejected: 	13203
# Iteration: 	189 / 1000
# Confirmed: 	84
# Tentative: 	87
# Rejected: 	13203
# Iteration: 	190 / 1000
# Confirmed: 	84
# Tentative: 	87
# Rejected: 	13203
# Iteration: 	191 / 1000
# Confirmed: 	84
# Tentative: 	87
# Rejected: 	13203
# Iteration: 	192 / 1000
# Confirmed: 	84
# Tentative: 	87
# Rejected: 	13203
# Iteration: 	193 / 1000
# Confirmed: 	84
# Tentative: 	87
# Rejected: 	13203
# Iteration: 	194 / 1000
# Confirmed: 	84
# Tentative: 	87
# Rejected: 	13203
# Iteration: 	195 / 1000
# Confirmed: 	84
# Tentative: 	87
# Rejected: 	13203
# Iteration: 	196 / 1000
# Confirmed: 	84
# Tentative: 	87
# Rejected: 	13203
# Iteration: 	197 / 1000
# Confirmed: 	84
# Tentative: 	87
# Rejected: 	13203
# Iteration: 	198 / 1000
# Confirmed: 	84
# Tentative: 	87
# Rejected: 	13203
# Iteration: 	199 / 1000
# Confirmed: 	84
# Tentative: 	87
# Rejected: 	13203
# Iteration: 	200 / 1000
# Confirmed: 	84
# Tentative: 	87
# Rejected: 	13203
# Iteration: 	201 / 1000
# Confirmed: 	84
# Tentative: 	87
# Rejected: 	13203
# Iteration: 	202 / 1000
# Confirmed: 	84
# Tentative: 	87
# Rejected: 	13203
# Iteration: 	203 / 1000
# Confirmed: 	84
# Tentative: 	86
# Rejected: 	13204
# Iteration: 	204 / 1000
# Confirmed: 	84
# Tentative: 	86
# Rejected: 	13204
# Iteration: 	205 / 1000
# Confirmed: 	84
# Tentative: 	86
# Rejected: 	13204
# Iteration: 	206 / 1000
# Confirmed: 	84
# Tentative: 	86
# Rejected: 	13204
# Iteration: 	207 / 1000
# Confirmed: 	84
# Tentative: 	86
# Rejected: 	13204
# Iteration: 	208 / 1000
# Confirmed: 	84
# Tentative: 	86
# Rejected: 	13204
# Iteration: 	209 / 1000
# Confirmed: 	84
# Tentative: 	86
# Rejected: 	13204
# Iteration: 	210 / 1000
# Confirmed: 	85
# Tentative: 	85
# Rejected: 	13204
# Iteration: 	211 / 1000
# Confirmed: 	85
# Tentative: 	85
# Rejected: 	13204
# Iteration: 	212 / 1000
# Confirmed: 	85
# Tentative: 	85
# Rejected: 	13204
# Iteration: 	213 / 1000
# Confirmed: 	85
# Tentative: 	85
# Rejected: 	13204
# Iteration: 	214 / 1000
# Confirmed: 	85
# Tentative: 	85
# Rejected: 	13204
# Iteration: 	215 / 1000
# Confirmed: 	85
# Tentative: 	85
# Rejected: 	13204
# Iteration: 	216 / 1000
# Confirmed: 	85
# Tentative: 	85
# Rejected: 	13204
# Iteration: 	217 / 1000
# Confirmed: 	85
# Tentative: 	85
# Rejected: 	13204
# Iteration: 	218 / 1000
# Confirmed: 	85
# Tentative: 	85
# Rejected: 	13204
# Iteration: 	219 / 1000
# Confirmed: 	85
# Tentative: 	85
# Rejected: 	13204
# Iteration: 	220 / 1000
# Confirmed: 	85
# Tentative: 	85
# Rejected: 	13204
# Iteration: 	221 / 1000
# Confirmed: 	85
# Tentative: 	85
# Rejected: 	13204
# Iteration: 	222 / 1000
# Confirmed: 	85
# Tentative: 	85
# Rejected: 	13204
# Iteration: 	223 / 1000
# Confirmed: 	85
# Tentative: 	85
# Rejected: 	13204
# Iteration: 	224 / 1000
# Confirmed: 	85
# Tentative: 	84
# Rejected: 	13205
# Iteration: 	225 / 1000
# Confirmed: 	85
# Tentative: 	84
# Rejected: 	13205
# Iteration: 	226 / 1000
# Confirmed: 	85
# Tentative: 	84
# Rejected: 	13205
# Iteration: 	227 / 1000
# Confirmed: 	85
# Tentative: 	84
# Rejected: 	13205
# Iteration: 	228 / 1000
# Confirmed: 	85
# Tentative: 	84
# Rejected: 	13205
# Iteration: 	229 / 1000
# Confirmed: 	85
# Tentative: 	84
# Rejected: 	13205
# Iteration: 	230 / 1000
# Confirmed: 	85
# Tentative: 	84
# Rejected: 	13205
# Iteration: 	231 / 1000
# Confirmed: 	85
# Tentative: 	84
# Rejected: 	13205
# Iteration: 	232 / 1000
# Confirmed: 	85
# Tentative: 	84
# Rejected: 	13205
# Iteration: 	233 / 1000
# Confirmed: 	85
# Tentative: 	83
# Rejected: 	13206
# Iteration: 	234 / 1000
# Confirmed: 	85
# Tentative: 	83
# Rejected: 	13206
# Iteration: 	235 / 1000
# Confirmed: 	86
# Tentative: 	81
# Rejected: 	13207
# Iteration: 	236 / 1000
# Confirmed: 	86
# Tentative: 	81
# Rejected: 	13207
# Iteration: 	237 / 1000
# Confirmed: 	86
# Tentative: 	81
# Rejected: 	13207
# Iteration: 	238 / 1000
# Confirmed: 	86
# Tentative: 	81
# Rejected: 	13207
# Iteration: 	239 / 1000
# Confirmed: 	86
# Tentative: 	81
# Rejected: 	13207
# Iteration: 	240 / 1000
# Confirmed: 	86
# Tentative: 	81
# Rejected: 	13207
# Iteration: 	241 / 1000
# Confirmed: 	86
# Tentative: 	81
# Rejected: 	13207
# Iteration: 	242 / 1000
# Confirmed: 	86
# Tentative: 	81
# Rejected: 	13207
# Iteration: 	243 / 1000
# Confirmed: 	86
# Tentative: 	81
# Rejected: 	13207
# Iteration: 	244 / 1000
# Confirmed: 	87
# Tentative: 	80
# Rejected: 	13207
# Iteration: 	245 / 1000
# Confirmed: 	87
# Tentative: 	80
# Rejected: 	13207
# Iteration: 	246 / 1000
# Confirmed: 	87
# Tentative: 	80
# Rejected: 	13207
# Iteration: 	247 / 1000
# Confirmed: 	87
# Tentative: 	80
# Rejected: 	13207
# Iteration: 	248 / 1000
# Confirmed: 	87
# Tentative: 	80
# Rejected: 	13207
# Iteration: 	249 / 1000
# Confirmed: 	87
# Tentative: 	80
# Rejected: 	13207
# Iteration: 	250 / 1000
# Confirmed: 	87
# Tentative: 	80
# Rejected: 	13207
# Iteration: 	251 / 1000
# Confirmed: 	87
# Tentative: 	80
# Rejected: 	13207
# Iteration: 	252 / 1000
# Confirmed: 	87
# Tentative: 	80
# Rejected: 	13207
# Iteration: 	253 / 1000
# Confirmed: 	87
# Tentative: 	80
# Rejected: 	13207
# Iteration: 	254 / 1000
# Confirmed: 	87
# Tentative: 	80
# Rejected: 	13207
# Iteration: 	255 / 1000
# Confirmed: 	87
# Tentative: 	80
# Rejected: 	13207
# Iteration: 	256 / 1000
# Confirmed: 	87
# Tentative: 	80
# Rejected: 	13207
# Iteration: 	257 / 1000
# Confirmed: 	87
# Tentative: 	80
# Rejected: 	13207
# Iteration: 	258 / 1000
# Confirmed: 	87
# Tentative: 	80
# Rejected: 	13207
# Iteration: 	259 / 1000
# Confirmed: 	87
# Tentative: 	80
# Rejected: 	13207
# Iteration: 	260 / 1000
# Confirmed: 	87
# Tentative: 	80
# Rejected: 	13207
# Iteration: 	261 / 1000
# Confirmed: 	87
# Tentative: 	80
# Rejected: 	13207
# Iteration: 	262 / 1000
# Confirmed: 	87
# Tentative: 	80
# Rejected: 	13207
# Iteration: 	263 / 1000
# Confirmed: 	87
# Tentative: 	80
# Rejected: 	13207
# Iteration: 	264 / 1000
# Confirmed: 	87
# Tentative: 	80
# Rejected: 	13207
# Iteration: 	265 / 1000
# Confirmed: 	88
# Tentative: 	79
# Rejected: 	13207
# Iteration: 	266 / 1000
# Confirmed: 	88
# Tentative: 	79
# Rejected: 	13207
# Iteration: 	267 / 1000
# Confirmed: 	88
# Tentative: 	79
# Rejected: 	13207
# Iteration: 	268 / 1000
# Confirmed: 	88
# Tentative: 	79
# Rejected: 	13207
# Iteration: 	269 / 1000
# Confirmed: 	88
# Tentative: 	79
# Rejected: 	13207
# Iteration: 	270 / 1000
# Confirmed: 	88
# Tentative: 	79
# Rejected: 	13207
# Iteration: 	271 / 1000
# Confirmed: 	88
# Tentative: 	79
# Rejected: 	13207
# Iteration: 	272 / 1000
# Confirmed: 	88
# Tentative: 	79
# Rejected: 	13207
# Iteration: 	273 / 1000
# Confirmed: 	88
# Tentative: 	79
# Rejected: 	13207
# Iteration: 	274 / 1000
# Confirmed: 	88
# Tentative: 	79
# Rejected: 	13207
# Iteration: 	275 / 1000
# Confirmed: 	88
# Tentative: 	79
# Rejected: 	13207
# Iteration: 	276 / 1000
# Confirmed: 	88
# Tentative: 	79
# Rejected: 	13207
# Iteration: 	277 / 1000
# Confirmed: 	88
# Tentative: 	79
# Rejected: 	13207
# Iteration: 	278 / 1000
# Confirmed: 	88
# Tentative: 	79
# Rejected: 	13207
# Iteration: 	279 / 1000
# Confirmed: 	88
# Tentative: 	79
# Rejected: 	13207
# Iteration: 	280 / 1000
# Confirmed: 	88
# Tentative: 	79
# Rejected: 	13207
# Iteration: 	281 / 1000
# Confirmed: 	88
# Tentative: 	79
# Rejected: 	13207
# Iteration: 	282 / 1000
# Confirmed: 	88
# Tentative: 	79
# Rejected: 	13207
# Iteration: 	283 / 1000
# Confirmed: 	88
# Tentative: 	79
# Rejected: 	13207
# Iteration: 	284 / 1000
# Confirmed: 	88
# Tentative: 	79
# Rejected: 	13207
# Iteration: 	285 / 1000
# Confirmed: 	88
# Tentative: 	79
# Rejected: 	13207
# Iteration: 	286 / 1000
# Confirmed: 	88
# Tentative: 	79
# Rejected: 	13207
# Iteration: 	287 / 1000
# Confirmed: 	88
# Tentative: 	79
# Rejected: 	13207
# Iteration: 	288 / 1000
# Confirmed: 	88
# Tentative: 	79
# Rejected: 	13207
# Iteration: 	289 / 1000
# Confirmed: 	88
# Tentative: 	79
# Rejected: 	13207
# Iteration: 	290 / 1000
# Confirmed: 	88
# Tentative: 	79
# Rejected: 	13207
# Iteration: 	291 / 1000
# Confirmed: 	88
# Tentative: 	79
# Rejected: 	13207
# Iteration: 	292 / 1000
# Confirmed: 	88
# Tentative: 	79
# Rejected: 	13207
# Iteration: 	293 / 1000
# Confirmed: 	88
# Tentative: 	79
# Rejected: 	13207
# Iteration: 	294 / 1000
# Confirmed: 	88
# Tentative: 	79
# Rejected: 	13207
# Iteration: 	295 / 1000
# Confirmed: 	88
# Tentative: 	78
# Rejected: 	13208
# Iteration: 	296 / 1000
# Confirmed: 	88
# Tentative: 	78
# Rejected: 	13208
# Iteration: 	297 / 1000
# Confirmed: 	88
# Tentative: 	78
# Rejected: 	13208
# Iteration: 	298 / 1000
# Confirmed: 	88
# Tentative: 	78
# Rejected: 	13208
# Iteration: 	299 / 1000
# Confirmed: 	88
# Tentative: 	78
# Rejected: 	13208
# Iteration: 	300 / 1000
# Confirmed: 	88
# Tentative: 	78
# Rejected: 	13208
# Iteration: 	301 / 1000
# Confirmed: 	88
# Tentative: 	78
# Rejected: 	13208
# Iteration: 	302 / 1000
# Confirmed: 	88
# Tentative: 	78
# Rejected: 	13208
# Iteration: 	303 / 1000
# Confirmed: 	88
# Tentative: 	78
# Rejected: 	13208
# Iteration: 	304 / 1000
# Confirmed: 	88
# Tentative: 	78
# Rejected: 	13208
# Iteration: 	305 / 1000
# Confirmed: 	88
# Tentative: 	78
# Rejected: 	13208
# Iteration: 	306 / 1000
# Confirmed: 	88
# Tentative: 	78
# Rejected: 	13208
# Iteration: 	307 / 1000
# Confirmed: 	88
# Tentative: 	78
# Rejected: 	13208
# Iteration: 	308 / 1000
# Confirmed: 	89
# Tentative: 	77
# Rejected: 	13208
# Iteration: 	309 / 1000
# Confirmed: 	89
# Tentative: 	77
# Rejected: 	13208
# Iteration: 	310 / 1000
# Confirmed: 	89
# Tentative: 	77
# Rejected: 	13208
# Iteration: 	311 / 1000
# Confirmed: 	89
# Tentative: 	77
# Rejected: 	13208
# Iteration: 	312 / 1000
# Confirmed: 	89
# Tentative: 	77
# Rejected: 	13208
# Iteration: 	313 / 1000
# Confirmed: 	90
# Tentative: 	76
# Rejected: 	13208
# Iteration: 	314 / 1000
# Confirmed: 	90
# Tentative: 	76
# Rejected: 	13208
# Iteration: 	315 / 1000
# Confirmed: 	90
# Tentative: 	76
# Rejected: 	13208
# Iteration: 	316 / 1000
# Confirmed: 	90
# Tentative: 	76
# Rejected: 	13208
# Iteration: 	317 / 1000
# Confirmed: 	90
# Tentative: 	76
# Rejected: 	13208
# Iteration: 	318 / 1000
# Confirmed: 	90
# Tentative: 	76
# Rejected: 	13208
# Iteration: 	319 / 1000
# Confirmed: 	90
# Tentative: 	76
# Rejected: 	13208
# Iteration: 	320 / 1000
# Confirmed: 	90
# Tentative: 	76
# Rejected: 	13208
# Iteration: 	321 / 1000
# Confirmed: 	90
# Tentative: 	76
# Rejected: 	13208
# Iteration: 	322 / 1000
# Confirmed: 	90
# Tentative: 	76
# Rejected: 	13208
# Iteration: 	323 / 1000
# Confirmed: 	90
# Tentative: 	76
# Rejected: 	13208
# Iteration: 	324 / 1000
# Confirmed: 	90
# Tentative: 	76
# Rejected: 	13208
# Iteration: 	325 / 1000
# Confirmed: 	90
# Tentative: 	76
# Rejected: 	13208
# Iteration: 	326 / 1000
# Confirmed: 	90
# Tentative: 	76
# Rejected: 	13208
# Iteration: 	327 / 1000
# Confirmed: 	90
# Tentative: 	76
# Rejected: 	13208
# Iteration: 	328 / 1000
# Confirmed: 	90
# Tentative: 	76
# Rejected: 	13208
# Iteration: 	329 / 1000
# Confirmed: 	90
# Tentative: 	75
# Rejected: 	13209
# Iteration: 	330 / 1000
# Confirmed: 	90
# Tentative: 	75
# Rejected: 	13209
# Iteration: 	331 / 1000
# Confirmed: 	91
# Tentative: 	74
# Rejected: 	13209
# Iteration: 	332 / 1000
# Confirmed: 	91
# Tentative: 	74
# Rejected: 	13209
# Iteration: 	333 / 1000
# Confirmed: 	92
# Tentative: 	73
# Rejected: 	13209
# Iteration: 	334 / 1000
# Confirmed: 	92
# Tentative: 	73
# Rejected: 	13209
# Iteration: 	335 / 1000
# Confirmed: 	92
# Tentative: 	73
# Rejected: 	13209
# Iteration: 	336 / 1000
# Confirmed: 	92
# Tentative: 	73
# Rejected: 	13209
# Iteration: 	337 / 1000
# Confirmed: 	92
# Tentative: 	73
# Rejected: 	13209
# Iteration: 	338 / 1000
# Confirmed: 	92
# Tentative: 	73
# Rejected: 	13209
# Iteration: 	339 / 1000
# Confirmed: 	92
# Tentative: 	73
# Rejected: 	13209
# Iteration: 	340 / 1000
# Confirmed: 	92
# Tentative: 	73
# Rejected: 	13209
# Iteration: 	341 / 1000
# Confirmed: 	92
# Tentative: 	73
# Rejected: 	13209
# Iteration: 	342 / 1000
# Confirmed: 	92
# Tentative: 	73
# Rejected: 	13209
# Iteration: 	343 / 1000
# Confirmed: 	92
# Tentative: 	73
# Rejected: 	13209
# Iteration: 	344 / 1000
# Confirmed: 	92
# Tentative: 	73
# Rejected: 	13209
# Iteration: 	345 / 1000
# Confirmed: 	92
# Tentative: 	73
# Rejected: 	13209
# Iteration: 	346 / 1000
# Confirmed: 	92
# Tentative: 	73
# Rejected: 	13209
# Iteration: 	347 / 1000
# Confirmed: 	92
# Tentative: 	73
# Rejected: 	13209
# Iteration: 	348 / 1000
# Confirmed: 	92
# Tentative: 	73
# Rejected: 	13209
# Iteration: 	349 / 1000
# Confirmed: 	92
# Tentative: 	73
# Rejected: 	13209
# Iteration: 	350 / 1000
# Confirmed: 	92
# Tentative: 	73
# Rejected: 	13209
# Iteration: 	351 / 1000
# Confirmed: 	92
# Tentative: 	73
# Rejected: 	13209
# Iteration: 	352 / 1000
# Confirmed: 	92
# Tentative: 	73
# Rejected: 	13209
# Iteration: 	353 / 1000
# Confirmed: 	92
# Tentative: 	73
# Rejected: 	13209
# Iteration: 	354 / 1000
# Confirmed: 	92
# Tentative: 	73
# Rejected: 	13209
# Iteration: 	355 / 1000
# Confirmed: 	92
# Tentative: 	73
# Rejected: 	13209
# Iteration: 	356 / 1000
# Confirmed: 	92
# Tentative: 	73
# Rejected: 	13209
# Iteration: 	357 / 1000
# Confirmed: 	92
# Tentative: 	73
# Rejected: 	13209
# Iteration: 	358 / 1000
# Confirmed: 	92
# Tentative: 	73
# Rejected: 	13209
# Iteration: 	359 / 1000
# Confirmed: 	92
# Tentative: 	73
# Rejected: 	13209
# Iteration: 	360 / 1000
# Confirmed: 	93
# Tentative: 	72
# Rejected: 	13209
# Iteration: 	361 / 1000
# Confirmed: 	93
# Tentative: 	72
# Rejected: 	13209
# Iteration: 	362 / 1000
# Confirmed: 	93
# Tentative: 	72
# Rejected: 	13209
# Iteration: 	363 / 1000
# Confirmed: 	93
# Tentative: 	72
# Rejected: 	13209
# Iteration: 	364 / 1000
# Confirmed: 	93
# Tentative: 	72
# Rejected: 	13209
# Iteration: 	365 / 1000
# Confirmed: 	93
# Tentative: 	72
# Rejected: 	13209
# Iteration: 	366 / 1000
# Confirmed: 	93
# Tentative: 	72
# Rejected: 	13209
# Iteration: 	367 / 1000
# Confirmed: 	93
# Tentative: 	72
# Rejected: 	13209
# Iteration: 	368 / 1000
# Confirmed: 	93
# Tentative: 	72
# Rejected: 	13209
# Iteration: 	369 / 1000
# Confirmed: 	93
# Tentative: 	72
# Rejected: 	13209
# Iteration: 	370 / 1000
# Confirmed: 	93
# Tentative: 	72
# Rejected: 	13209
# Iteration: 	371 / 1000
# Confirmed: 	93
# Tentative: 	72
# Rejected: 	13209
# Iteration: 	372 / 1000
# Confirmed: 	93
# Tentative: 	72
# Rejected: 	13209
# Iteration: 	373 / 1000
# Confirmed: 	93
# Tentative: 	72
# Rejected: 	13209
# Iteration: 	374 / 1000
# Confirmed: 	93
# Tentative: 	72
# Rejected: 	13209
# Iteration: 	375 / 1000
# Confirmed: 	93
# Tentative: 	72
# Rejected: 	13209
# Iteration: 	376 / 1000
# Confirmed: 	93
# Tentative: 	72
# Rejected: 	13209
# Iteration: 	377 / 1000
# Confirmed: 	93
# Tentative: 	72
# Rejected: 	13209
# Iteration: 	378 / 1000
# Confirmed: 	93
# Tentative: 	72
# Rejected: 	13209
# Iteration: 	379 / 1000
# Confirmed: 	93
# Tentative: 	72
# Rejected: 	13209
# Iteration: 	380 / 1000
# Confirmed: 	93
# Tentative: 	71
# Rejected: 	13210
# Iteration: 	381 / 1000
# Confirmed: 	93
# Tentative: 	71
# Rejected: 	13210
# Iteration: 	382 / 1000
# Confirmed: 	93
# Tentative: 	71
# Rejected: 	13210
# Iteration: 	383 / 1000
# Confirmed: 	95
# Tentative: 	69
# Rejected: 	13210
# Iteration: 	384 / 1000
# Confirmed: 	95
# Tentative: 	69
# Rejected: 	13210
# Iteration: 	385 / 1000
# Confirmed: 	95
# Tentative: 	69
# Rejected: 	13210
# Iteration: 	386 / 1000
# Confirmed: 	95
# Tentative: 	69
# Rejected: 	13210
# Iteration: 	387 / 1000
# Confirmed: 	95
# Tentative: 	69
# Rejected: 	13210
# Iteration: 	388 / 1000
# Confirmed: 	95
# Tentative: 	69
# Rejected: 	13210
# Iteration: 	389 / 1000
# Confirmed: 	95
# Tentative: 	69
# Rejected: 	13210
# Iteration: 	390 / 1000
# Confirmed: 	95
# Tentative: 	69
# Rejected: 	13210
# Iteration: 	391 / 1000
# Confirmed: 	95
# Tentative: 	69
# Rejected: 	13210
# Iteration: 	392 / 1000
# Confirmed: 	96
# Tentative: 	68
# Rejected: 	13210
# Iteration: 	393 / 1000
# Confirmed: 	96
# Tentative: 	68
# Rejected: 	13210
# Iteration: 	394 / 1000
# Confirmed: 	96
# Tentative: 	68
# Rejected: 	13210
# Iteration: 	395 / 1000
# Confirmed: 	96
# Tentative: 	68
# Rejected: 	13210
# Iteration: 	396 / 1000
# Confirmed: 	96
# Tentative: 	68
# Rejected: 	13210
# Iteration: 	397 / 1000
# Confirmed: 	96
# Tentative: 	68
# Rejected: 	13210
# Iteration: 	398 / 1000
# Confirmed: 	96
# Tentative: 	68
# Rejected: 	13210
# Iteration: 	399 / 1000
# Confirmed: 	96
# Tentative: 	68
# Rejected: 	13210
# Iteration: 	400 / 1000
# Confirmed: 	96
# Tentative: 	68
# Rejected: 	13210
# Iteration: 	401 / 1000
# Confirmed: 	96
# Tentative: 	68
# Rejected: 	13210
# Iteration: 	402 / 1000
# Confirmed: 	96
# Tentative: 	68
# Rejected: 	13210
# Iteration: 	403 / 1000
# Confirmed: 	96
# Tentative: 	68
# Rejected: 	13210
# Iteration: 	404 / 1000
# Confirmed: 	96
# Tentative: 	68
# Rejected: 	13210
# Iteration: 	405 / 1000
# Confirmed: 	97
# Tentative: 	67
# Rejected: 	13210
# Iteration: 	406 / 1000
# Confirmed: 	97
# Tentative: 	67
# Rejected: 	13210
# Iteration: 	407 / 1000
# Confirmed: 	97
# Tentative: 	67
# Rejected: 	13210
# Iteration: 	408 / 1000
# Confirmed: 	97
# Tentative: 	67
# Rejected: 	13210
# Iteration: 	409 / 1000
# Confirmed: 	97
# Tentative: 	67
# Rejected: 	13210
# Iteration: 	410 / 1000
# Confirmed: 	97
# Tentative: 	67
# Rejected: 	13210
# Iteration: 	411 / 1000
# Confirmed: 	97
# Tentative: 	67
# Rejected: 	13210
# Iteration: 	412 / 1000
# Confirmed: 	97
# Tentative: 	67
# Rejected: 	13210
# Iteration: 	413 / 1000
# Confirmed: 	97
# Tentative: 	67
# Rejected: 	13210
# Iteration: 	414 / 1000
# Confirmed: 	97
# Tentative: 	67
# Rejected: 	13210
# Iteration: 	415 / 1000
# Confirmed: 	97
# Tentative: 	67
# Rejected: 	13210
# Iteration: 	416 / 1000
# Confirmed: 	97
# Tentative: 	66
# Rejected: 	13211
# Iteration: 	417 / 1000
# Confirmed: 	97
# Tentative: 	66
# Rejected: 	13211
# Iteration: 	418 / 1000
# Confirmed: 	97
# Tentative: 	66
# Rejected: 	13211
# Iteration: 	419 / 1000
# Confirmed: 	97
# Tentative: 	66
# Rejected: 	13211
# Iteration: 	420 / 1000
# Confirmed: 	97
# Tentative: 	66
# Rejected: 	13211
# Iteration: 	421 / 1000
# Confirmed: 	97
# Tentative: 	66
# Rejected: 	13211
# Iteration: 	422 / 1000
# Confirmed: 	97
# Tentative: 	66
# Rejected: 	13211
# Iteration: 	423 / 1000
# Confirmed: 	97
# Tentative: 	66
# Rejected: 	13211
# Iteration: 	424 / 1000
# Confirmed: 	97
# Tentative: 	66
# Rejected: 	13211
# Iteration: 	425 / 1000
# Confirmed: 	97
# Tentative: 	66
# Rejected: 	13211
# Iteration: 	426 / 1000
# Confirmed: 	97
# Tentative: 	66
# Rejected: 	13211
# Iteration: 	427 / 1000
# Confirmed: 	97
# Tentative: 	66
# Rejected: 	13211
# Iteration: 	428 / 1000
# Confirmed: 	97
# Tentative: 	66
# Rejected: 	13211
# Iteration: 	429 / 1000
# Confirmed: 	97
# Tentative: 	66
# Rejected: 	13211
# Iteration: 	430 / 1000
# Confirmed: 	99
# Tentative: 	64
# Rejected: 	13211
# Iteration: 	431 / 1000
# Confirmed: 	99
# Tentative: 	64
# Rejected: 	13211
# Iteration: 	432 / 1000
# Confirmed: 	99
# Tentative: 	64
# Rejected: 	13211
# Iteration: 	433 / 1000
# Confirmed: 	99
# Tentative: 	64
# Rejected: 	13211
# Iteration: 	434 / 1000
# Confirmed: 	99
# Tentative: 	64
# Rejected: 	13211
# Iteration: 	435 / 1000
# Confirmed: 	99
# Tentative: 	64
# Rejected: 	13211
# Iteration: 	436 / 1000
# Confirmed: 	99
# Tentative: 	64
# Rejected: 	13211
# Iteration: 	437 / 1000
# Confirmed: 	99
# Tentative: 	64
# Rejected: 	13211
# Iteration: 	438 / 1000
# Confirmed: 	99
# Tentative: 	64
# Rejected: 	13211
# Iteration: 	439 / 1000
# Confirmed: 	99
# Tentative: 	64
# Rejected: 	13211
# Iteration: 	440 / 1000
# Confirmed: 	99
# Tentative: 	64
# Rejected: 	13211
# Iteration: 	441 / 1000
# Confirmed: 	99
# Tentative: 	64
# Rejected: 	13211
# Iteration: 	442 / 1000
# Confirmed: 	99
# Tentative: 	64
# Rejected: 	13211
# Iteration: 	443 / 1000
# Confirmed: 	100
# Tentative: 	63
# Rejected: 	13211
# Iteration: 	444 / 1000
# Confirmed: 	100
# Tentative: 	63
# Rejected: 	13211
# Iteration: 	445 / 1000
# Confirmed: 	100
# Tentative: 	63
# Rejected: 	13211
# Iteration: 	446 / 1000
# Confirmed: 	100
# Tentative: 	63
# Rejected: 	13211
# Iteration: 	447 / 1000
# Confirmed: 	100
# Tentative: 	63
# Rejected: 	13211
# Iteration: 	448 / 1000
# Confirmed: 	100
# Tentative: 	63
# Rejected: 	13211
# Iteration: 	449 / 1000
# Confirmed: 	100
# Tentative: 	63
# Rejected: 	13211
# Iteration: 	450 / 1000
# Confirmed: 	100
# Tentative: 	63
# Rejected: 	13211
# Iteration: 	451 / 1000
# Confirmed: 	100
# Tentative: 	63
# Rejected: 	13211
# Iteration: 	452 / 1000
# Confirmed: 	100
# Tentative: 	63
# Rejected: 	13211
# Iteration: 	453 / 1000
# Confirmed: 	100
# Tentative: 	63
# Rejected: 	13211
# Iteration: 	454 / 1000
# Confirmed: 	100
# Tentative: 	63
# Rejected: 	13211
# Iteration: 	455 / 1000
# Confirmed: 	100
# Tentative: 	63
# Rejected: 	13211
# Iteration: 	456 / 1000
# Confirmed: 	100
# Tentative: 	63
# Rejected: 	13211
# Iteration: 	457 / 1000
# Confirmed: 	100
# Tentative: 	63
# Rejected: 	13211
# Iteration: 	458 / 1000
# Confirmed: 	101
# Tentative: 	62
# Rejected: 	13211
# Iteration: 	459 / 1000
# Confirmed: 	101
# Tentative: 	62
# Rejected: 	13211
# Iteration: 	460 / 1000
# Confirmed: 	101
# Tentative: 	62
# Rejected: 	13211
# Iteration: 	461 / 1000
# Confirmed: 	101
# Tentative: 	62
# Rejected: 	13211
# Iteration: 	462 / 1000
# Confirmed: 	101
# Tentative: 	62
# Rejected: 	13211
# Iteration: 	463 / 1000
# Confirmed: 	101
# Tentative: 	62
# Rejected: 	13211
# Iteration: 	464 / 1000
# Confirmed: 	101
# Tentative: 	62
# Rejected: 	13211
# Iteration: 	465 / 1000
# Confirmed: 	101
# Tentative: 	62
# Rejected: 	13211
# Iteration: 	466 / 1000
# Confirmed: 	101
# Tentative: 	62
# Rejected: 	13211
# Iteration: 	467 / 1000
# Confirmed: 	101
# Tentative: 	61
# Rejected: 	13212
# Iteration: 	468 / 1000
# Confirmed: 	101
# Tentative: 	61
# Rejected: 	13212
# Iteration: 	469 / 1000
# Confirmed: 	101
# Tentative: 	61
# Rejected: 	13212
# Iteration: 	470 / 1000
# Confirmed: 	101
# Tentative: 	61
# Rejected: 	13212
# Iteration: 	471 / 1000
# Confirmed: 	101
# Tentative: 	61
# Rejected: 	13212
# Iteration: 	472 / 1000
# Confirmed: 	101
# Tentative: 	61
# Rejected: 	13212
# Iteration: 	473 / 1000
# Confirmed: 	101
# Tentative: 	61
# Rejected: 	13212
# Iteration: 	474 / 1000
# Confirmed: 	101
# Tentative: 	61
# Rejected: 	13212
# Iteration: 	475 / 1000
# Confirmed: 	101
# Tentative: 	61
# Rejected: 	13212
# Iteration: 	476 / 1000
# Confirmed: 	101
# Tentative: 	61
# Rejected: 	13212
# Iteration: 	477 / 1000
# Confirmed: 	101
# Tentative: 	61
# Rejected: 	13212
# Iteration: 	478 / 1000
# Confirmed: 	101
# Tentative: 	61
# Rejected: 	13212
# Iteration: 	479 / 1000
# Confirmed: 	101
# Tentative: 	61
# Rejected: 	13212
# Iteration: 	480 / 1000
# Confirmed: 	101
# Tentative: 	61
# Rejected: 	13212
# Iteration: 	481 / 1000
# Confirmed: 	101
# Tentative: 	61
# Rejected: 	13212
# Iteration: 	482 / 1000
# Confirmed: 	101
# Tentative: 	61
# Rejected: 	13212
# Iteration: 	483 / 1000
# Confirmed: 	101
# Tentative: 	61
# Rejected: 	13212
# Iteration: 	484 / 1000
# Confirmed: 	101
# Tentative: 	61
# Rejected: 	13212
# Iteration: 	485 / 1000
# Confirmed: 	101
# Tentative: 	61
# Rejected: 	13212
# Iteration: 	486 / 1000
# Confirmed: 	101
# Tentative: 	61
# Rejected: 	13212
# Iteration: 	487 / 1000
# Confirmed: 	101
# Tentative: 	61
# Rejected: 	13212
# Iteration: 	488 / 1000
# Confirmed: 	101
# Tentative: 	61
# Rejected: 	13212
# Iteration: 	489 / 1000
# Confirmed: 	101
# Tentative: 	61
# Rejected: 	13212
# Iteration: 	490 / 1000
# Confirmed: 	101
# Tentative: 	61
# Rejected: 	13212
# Iteration: 	491 / 1000
# Confirmed: 	101
# Tentative: 	61
# Rejected: 	13212
# Iteration: 	492 / 1000
# Confirmed: 	101
# Tentative: 	61
# Rejected: 	13212
# Iteration: 	493 / 1000
# Confirmed: 	101
# Tentative: 	61
# Rejected: 	13212
# Iteration: 	494 / 1000
# Confirmed: 	101
# Tentative: 	61
# Rejected: 	13212
# Iteration: 	495 / 1000
# Confirmed: 	101
# Tentative: 	61
# Rejected: 	13212
# Iteration: 	496 / 1000
# Confirmed: 	101
# Tentative: 	61
# Rejected: 	13212
# Iteration: 	497 / 1000
# Confirmed: 	101
# Tentative: 	61
# Rejected: 	13212
# Iteration: 	498 / 1000
# Confirmed: 	101
# Tentative: 	61
# Rejected: 	13212
# Iteration: 	499 / 1000
# Confirmed: 	101
# Tentative: 	61
# Rejected: 	13212
# Iteration: 	500 / 1000
# Confirmed: 	101
# Tentative: 	61
# Rejected: 	13212
# Iteration: 	501 / 1000
# Confirmed: 	101
# Tentative: 	61
# Rejected: 	13212
# Iteration: 	502 / 1000
# Confirmed: 	101
# Tentative: 	61
# Rejected: 	13212
# Iteration: 	503 / 1000
# Confirmed: 	102
# Tentative: 	60
# Rejected: 	13212
# Iteration: 	504 / 1000
# Confirmed: 	102
# Tentative: 	60
# Rejected: 	13212
# Iteration: 	505 / 1000
# Confirmed: 	102
# Tentative: 	60
# Rejected: 	13212
# Iteration: 	506 / 1000
# Confirmed: 	102
# Tentative: 	60
# Rejected: 	13212
# Iteration: 	507 / 1000
# Confirmed: 	102
# Tentative: 	60
# Rejected: 	13212
# Iteration: 	508 / 1000
# Confirmed: 	102
# Tentative: 	60
# Rejected: 	13212
# Iteration: 	509 / 1000
# Confirmed: 	102
# Tentative: 	60
# Rejected: 	13212
# Iteration: 	510 / 1000
# Confirmed: 	102
# Tentative: 	60
# Rejected: 	13212
# Iteration: 	511 / 1000
# Confirmed: 	102
# Tentative: 	60
# Rejected: 	13212
# Iteration: 	512 / 1000
# Confirmed: 	102
# Tentative: 	60
# Rejected: 	13212
# Iteration: 	513 / 1000
# Confirmed: 	102
# Tentative: 	60
# Rejected: 	13212
# Iteration: 	514 / 1000
# Confirmed: 	102
# Tentative: 	60
# Rejected: 	13212
# Iteration: 	515 / 1000
# Confirmed: 	102
# Tentative: 	60
# Rejected: 	13212
# Iteration: 	516 / 1000
# Confirmed: 	102
# Tentative: 	60
# Rejected: 	13212
# Iteration: 	517 / 1000
# Confirmed: 	102
# Tentative: 	60
# Rejected: 	13212
# Iteration: 	518 / 1000
# Confirmed: 	102
# Tentative: 	60
# Rejected: 	13212
# Iteration: 	519 / 1000
# Confirmed: 	102
# Tentative: 	60
# Rejected: 	13212
# Iteration: 	520 / 1000
# Confirmed: 	102
# Tentative: 	60
# Rejected: 	13212
# Iteration: 	521 / 1000
# Confirmed: 	102
# Tentative: 	60
# Rejected: 	13212
# Iteration: 	522 / 1000
# Confirmed: 	102
# Tentative: 	60
# Rejected: 	13212
# Iteration: 	523 / 1000
# Confirmed: 	102
# Tentative: 	60
# Rejected: 	13212
# Iteration: 	524 / 1000
# Confirmed: 	102
# Tentative: 	60
# Rejected: 	13212
# Iteration: 	525 / 1000
# Confirmed: 	102
# Tentative: 	60
# Rejected: 	13212
# Iteration: 	526 / 1000
# Confirmed: 	102
# Tentative: 	60
# Rejected: 	13212
# Iteration: 	527 / 1000
# Confirmed: 	102
# Tentative: 	60
# Rejected: 	13212
# Iteration: 	528 / 1000
# Confirmed: 	102
# Tentative: 	60
# Rejected: 	13212
# Iteration: 	529 / 1000
# Confirmed: 	102
# Tentative: 	60
# Rejected: 	13212
# Iteration: 	530 / 1000
# Confirmed: 	102
# Tentative: 	60
# Rejected: 	13212
# Iteration: 	531 / 1000
# Confirmed: 	102
# Tentative: 	60
# Rejected: 	13212
# Iteration: 	532 / 1000
# Confirmed: 	102
# Tentative: 	60
# Rejected: 	13212
# Iteration: 	533 / 1000
# Confirmed: 	102
# Tentative: 	60
# Rejected: 	13212
# Iteration: 	534 / 1000
# Confirmed: 	102
# Tentative: 	60
# Rejected: 	13212
# Iteration: 	535 / 1000
# Confirmed: 	102
# Tentative: 	60
# Rejected: 	13212
# Iteration: 	536 / 1000
# Confirmed: 	102
# Tentative: 	60
# Rejected: 	13212
# Iteration: 	537 / 1000
# Confirmed: 	102
# Tentative: 	60
# Rejected: 	13212
# Iteration: 	538 / 1000
# Confirmed: 	102
# Tentative: 	60
# Rejected: 	13212
# Iteration: 	539 / 1000
# Confirmed: 	102
# Tentative: 	60
# Rejected: 	13212
# Iteration: 	540 / 1000
# Confirmed: 	102
# Tentative: 	60
# Rejected: 	13212
# Iteration: 	541 / 1000
# Confirmed: 	102
# Tentative: 	60
# Rejected: 	13212
# Iteration: 	542 / 1000
# Confirmed: 	103
# Tentative: 	59
# Rejected: 	13212
# Iteration: 	543 / 1000
# Confirmed: 	103
# Tentative: 	59
# Rejected: 	13212
# Iteration: 	544 / 1000
# Confirmed: 	103
# Tentative: 	59
# Rejected: 	13212
# Iteration: 	545 / 1000
# Confirmed: 	103
# Tentative: 	59
# Rejected: 	13212
# Iteration: 	546 / 1000
# Confirmed: 	103
# Tentative: 	59
# Rejected: 	13212
# Iteration: 	547 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	548 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	549 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	550 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	551 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	552 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	553 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	554 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	555 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	556 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	557 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	558 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	559 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	560 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	561 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	562 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	563 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	564 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	565 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	566 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	567 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	568 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	569 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	570 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	571 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	572 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	573 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	574 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	575 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	576 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	577 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	578 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	579 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	580 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	581 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	582 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	583 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	584 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	585 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	586 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	587 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	588 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	589 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	590 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	591 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	592 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	593 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	594 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	595 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	596 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	597 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	598 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	599 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	600 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	601 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	602 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	603 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	604 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	605 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	606 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	607 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	608 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	609 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	610 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	611 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	612 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	613 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	614 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	615 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	616 / 1000
# Confirmed: 	104
# Tentative: 	58
# Rejected: 	13212
# Iteration: 	617 / 1000
# Confirmed: 	104
# Tentative: 	57
# Rejected: 	13213
# Iteration: 	618 / 1000
# Confirmed: 	104
# Tentative: 	57
# Rejected: 	13213
# Iteration: 	619 / 1000
# Confirmed: 	104
# Tentative: 	57
# Rejected: 	13213
# Iteration: 	620 / 1000
# Confirmed: 	104
# Tentative: 	57
# Rejected: 	13213
# Iteration: 	621 / 1000
# Confirmed: 	104
# Tentative: 	57
# Rejected: 	13213
# Iteration: 	622 / 1000
# Confirmed: 	104
# Tentative: 	57
# Rejected: 	13213
# Iteration: 	623 / 1000
# Confirmed: 	104
# Tentative: 	57
# Rejected: 	13213
# Iteration: 	624 / 1000
# Confirmed: 	104
# Tentative: 	57
# Rejected: 	13213
# Iteration: 	625 / 1000
# Confirmed: 	104
# Tentative: 	57
# Rejected: 	13213
# Iteration: 	626 / 1000
# Confirmed: 	105
# Tentative: 	56
# Rejected: 	13213
# Iteration: 	627 / 1000
# Confirmed: 	105
# Tentative: 	56
# Rejected: 	13213
# Iteration: 	628 / 1000
# Confirmed: 	105
# Tentative: 	56
# Rejected: 	13213
# Iteration: 	629 / 1000
# Confirmed: 	105
# Tentative: 	56
# Rejected: 	13213
# Iteration: 	630 / 1000
# Confirmed: 	105
# Tentative: 	56
# Rejected: 	13213
# Iteration: 	631 / 1000
# Confirmed: 	105
# Tentative: 	56
# Rejected: 	13213
# Iteration: 	632 / 1000
# Confirmed: 	105
# Tentative: 	56
# Rejected: 	13213
# Iteration: 	633 / 1000
# Confirmed: 	105
# Tentative: 	56
# Rejected: 	13213
# Iteration: 	634 / 1000
# Confirmed: 	105
# Tentative: 	56
# Rejected: 	13213
# Iteration: 	635 / 1000
# Confirmed: 	105
# Tentative: 	56
# Rejected: 	13213
# Iteration: 	636 / 1000
# Confirmed: 	105
# Tentative: 	56
# Rejected: 	13213
# Iteration: 	637 / 1000
# Confirmed: 	105
# Tentative: 	56
# Rejected: 	13213
# Iteration: 	638 / 1000
# Confirmed: 	105
# Tentative: 	56
# Rejected: 	13213
# Iteration: 	639 / 1000
# Confirmed: 	106
# Tentative: 	55
# Rejected: 	13213
# Iteration: 	640 / 1000
# Confirmed: 	106
# Tentative: 	55
# Rejected: 	13213
# Iteration: 	641 / 1000
# Confirmed: 	107
# Tentative: 	54
# Rejected: 	13213
# Iteration: 	642 / 1000
# Confirmed: 	107
# Tentative: 	54
# Rejected: 	13213
# Iteration: 	643 / 1000
# Confirmed: 	107
# Tentative: 	54
# Rejected: 	13213
# Iteration: 	644 / 1000
# Confirmed: 	107
# Tentative: 	54
# Rejected: 	13213
# Iteration: 	645 / 1000
# Confirmed: 	107
# Tentative: 	54
# Rejected: 	13213
# Iteration: 	646 / 1000
# Confirmed: 	107
# Tentative: 	54
# Rejected: 	13213
# Iteration: 	647 / 1000
# Confirmed: 	107
# Tentative: 	54
# Rejected: 	13213
# Iteration: 	648 / 1000
# Confirmed: 	107
# Tentative: 	54
# Rejected: 	13213
# Iteration: 	649 / 1000
# Confirmed: 	107
# Tentative: 	54
# Rejected: 	13213
# Iteration: 	650 / 1000
# Confirmed: 	107
# Tentative: 	54
# Rejected: 	13213
# Iteration: 	651 / 1000
# Confirmed: 	107
# Tentative: 	54
# Rejected: 	13213
# Iteration: 	652 / 1000
# Confirmed: 	107
# Tentative: 	54
# Rejected: 	13213
# Iteration: 	653 / 1000
# Confirmed: 	107
# Tentative: 	54
# Rejected: 	13213
# Iteration: 	654 / 1000
# Confirmed: 	107
# Tentative: 	54
# Rejected: 	13213
# Iteration: 	655 / 1000
# Confirmed: 	107
# Tentative: 	54
# Rejected: 	13213
# Iteration: 	656 / 1000
# Confirmed: 	107
# Tentative: 	54
# Rejected: 	13213
# Iteration: 	657 / 1000
# Confirmed: 	107
# Tentative: 	54
# Rejected: 	13213
# Iteration: 	658 / 1000
# Confirmed: 	107
# Tentative: 	54
# Rejected: 	13213
# Iteration: 	659 / 1000
# Confirmed: 	107
# Tentative: 	54
# Rejected: 	13213
# Iteration: 	660 / 1000
# Confirmed: 	107
# Tentative: 	54
# Rejected: 	13213
# Iteration: 	661 / 1000
# Confirmed: 	107
# Tentative: 	54
# Rejected: 	13213
# Iteration: 	662 / 1000
# Confirmed: 	107
# Tentative: 	54
# Rejected: 	13213
# Iteration: 	663 / 1000
# Confirmed: 	107
# Tentative: 	54
# Rejected: 	13213
# Iteration: 	664 / 1000
# Confirmed: 	107
# Tentative: 	54
# Rejected: 	13213
# Iteration: 	665 / 1000
# Confirmed: 	107
# Tentative: 	54
# Rejected: 	13213
# Iteration: 	666 / 1000
# Confirmed: 	107
# Tentative: 	54
# Rejected: 	13213
# Iteration: 	667 / 1000
# Confirmed: 	107
# Tentative: 	54
# Rejected: 	13213
# Iteration: 	668 / 1000
# Confirmed: 	107
# Tentative: 	54
# Rejected: 	13213
# Iteration: 	669 / 1000
# Confirmed: 	107
# Tentative: 	54
# Rejected: 	13213
# Iteration: 	670 / 1000
# Confirmed: 	107
# Tentative: 	54
# Rejected: 	13213
# Iteration: 	671 / 1000
# Confirmed: 	107
# Tentative: 	54
# Rejected: 	13213
# Iteration: 	672 / 1000
# Confirmed: 	107
# Tentative: 	54
# Rejected: 	13213
# Iteration: 	673 / 1000
# Confirmed: 	107
# Tentative: 	54
# Rejected: 	13213
# Iteration: 	674 / 1000
# Confirmed: 	107
# Tentative: 	54
# Rejected: 	13213
# Iteration: 	675 / 1000
# Confirmed: 	107
# Tentative: 	54
# Rejected: 	13213
# Iteration: 	676 / 1000
# Confirmed: 	107
# Tentative: 	54
# Rejected: 	13213
# Iteration: 	677 / 1000
# Confirmed: 	107
# Tentative: 	54
# Rejected: 	13213
# Iteration: 	678 / 1000
# Confirmed: 	107
# Tentative: 	53
# Rejected: 	13214
# Iteration: 	679 / 1000
# Confirmed: 	107
# Tentative: 	53
# Rejected: 	13214
# Iteration: 	680 / 1000
# Confirmed: 	107
# Tentative: 	53
# Rejected: 	13214
# Iteration: 	681 / 1000
# Confirmed: 	107
# Tentative: 	53
# Rejected: 	13214
# Iteration: 	682 / 1000
# Confirmed: 	107
# Tentative: 	53
# ...
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	777 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	778 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	779 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	780 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	781 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	782 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	783 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	784 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	785 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	786 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	787 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	788 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	789 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	790 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	791 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	792 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	793 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	794 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	795 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	796 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	797 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	798 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	799 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	800 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	801 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	802 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	803 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	804 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	805 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	806 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	807 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	808 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	809 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	810 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	811 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	812 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	813 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	814 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	815 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	816 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	817 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	818 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	819 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	820 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	821 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	822 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	823 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	824 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	825 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	826 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	827 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	828 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	829 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	830 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	831 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	832 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	833 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	834 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	835 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	836 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	837 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	838 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	839 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	840 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	841 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	842 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	843 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	844 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	845 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	846 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	847 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	848 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	849 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	850 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	851 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	852 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	853 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	854 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	855 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	856 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	857 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	858 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	859 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	860 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	861 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	862 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	863 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	864 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	865 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	866 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	867 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	868 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	869 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	870 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	871 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	872 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	873 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	874 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	875 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	876 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	877 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	878 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	879 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	880 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	881 / 1000
# Confirmed: 	110
# Tentative: 	50
# Rejected: 	13214
# Iteration: 	882 / 1000
# Confirmed: 	111
# Tentative: 	49
# Rejected: 	13214
# Iteration: 	883 / 1000
# Confirmed: 	111
# Tentative: 	49
# Rejected: 	13214
# Iteration: 	884 / 1000
# Confirmed: 	111
# Tentative: 	49
# Rejected: 	13214
# Iteration: 	885 / 1000
# Confirmed: 	111
# Tentative: 	49
# Rejected: 	13214
# Iteration: 	886 / 1000
# Confirmed: 	111
# Tentative: 	49
# Rejected: 	13214
# Iteration: 	887 / 1000
# Confirmed: 	111
# Tentative: 	49
# Rejected: 	13214
# Iteration: 	888 / 1000
# Confirmed: 	111
# Tentative: 	49
# Rejected: 	13214
# Iteration: 	889 / 1000
# Confirmed: 	111
# Tentative: 	49
# Rejected: 	13214
# Iteration: 	890 / 1000
# Confirmed: 	111
# Tentative: 	49
# Rejected: 	13214
# Iteration: 	891 / 1000
# Confirmed: 	111
# Tentative: 	49
# Rejected: 	13214
# Iteration: 	892 / 1000
# Confirmed: 	111
# Tentative: 	49
# Rejected: 	13214
# Iteration: 	893 / 1000
# Confirmed: 	111
# Tentative: 	49
# Rejected: 	13214
# Iteration: 	894 / 1000
# Confirmed: 	111
# Tentative: 	49
# Rejected: 	13214
# Iteration: 	895 / 1000
# Confirmed: 	111
# Tentative: 	49
# Rejected: 	13214
# Iteration: 	896 / 1000
# Confirmed: 	111
# Tentative: 	49
# Rejected: 	13214
# Iteration: 	897 / 1000
# Confirmed: 	111
# Tentative: 	49
# Rejected: 	13214
# Iteration: 	898 / 1000
# Confirmed: 	111
# Tentative: 	49
# Rejected: 	13214
# Iteration: 	899 / 1000
# Confirmed: 	111
# Tentative: 	49
# Rejected: 	13214
# Iteration: 	900 / 1000
# Confirmed: 	111
# Tentative: 	49
# Rejected: 	13214
# Iteration: 	901 / 1000
# Confirmed: 	112
# Tentative: 	48
# Rejected: 	13214
# Iteration: 	902 / 1000
# Confirmed: 	112
# Tentative: 	48
# Rejected: 	13214
# Iteration: 	903 / 1000
# Confirmed: 	112
# Tentative: 	48
# Rejected: 	13214
# Iteration: 	904 / 1000
# Confirmed: 	112
# Tentative: 	48
# Rejected: 	13214
# Iteration: 	905 / 1000
# Confirmed: 	112
# Tentative: 	48
# Rejected: 	13214
# Iteration: 	906 / 1000
# Confirmed: 	112
# Tentative: 	48
# Rejected: 	13214
# Iteration: 	907 / 1000
# Confirmed: 	112
# Tentative: 	48
# Rejected: 	13214
# Iteration: 	908 / 1000
# Confirmed: 	113
# Tentative: 	47
# Rejected: 	13214
# Iteration: 	909 / 1000
# Confirmed: 	113
# Tentative: 	47
# Rejected: 	13214
# Iteration: 	910 / 1000
# Confirmed: 	113
# Tentative: 	47
# Rejected: 	13214
# Iteration: 	911 / 1000
# Confirmed: 	113
# Tentative: 	47
# Rejected: 	13214
# Iteration: 	912 / 1000
# Confirmed: 	113
# Tentative: 	47
# Rejected: 	13214
# Iteration: 	913 / 1000
# Confirmed: 	113
# Tentative: 	47
# Rejected: 	13214
# Iteration: 	914 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	915 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	916 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	917 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	918 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	919 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	920 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	921 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	922 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	923 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	924 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	925 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	926 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	927 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	928 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	929 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	930 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	931 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	932 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	933 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	934 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	935 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	936 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	937 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	938 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	939 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	940 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	941 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	942 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	943 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	944 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	945 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	946 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	947 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	948 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	949 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	950 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	951 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	952 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	953 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	954 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	955 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	956 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	957 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	958 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	959 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	960 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	961 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	962 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	963 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	964 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	965 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	966 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	967 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	968 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	969 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	970 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	971 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	972 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	973 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	974 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	975 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	976 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	977 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	978 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	979 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	980 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	981 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	982 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	983 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	984 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	985 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	986 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	987 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	988 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	989 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	990 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	991 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	992 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	993 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	994 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	995 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	996 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	997 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	998 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
# Iteration: 	999 / 1000
# Confirmed: 	114
# Tentative: 	46
# Rejected: 	13214
#
#
# BorutaPy finished running.
#
# Iteration: 	1000 / 1000
# Confirmed: 	114
# Tentative: 	36
# Rejected: 	13224

# %%
selected_features_ln = GeneSelection(best_rf_ln,feat_ln,target_numeric_ln)
# Out:
# Iteration: 	1 / 1000
# Confirmed: 	0
# Tentative: 	3358
# Rejected: 	0
# Iteration: 	2 / 1000
# Confirmed: 	0
# Tentative: 	3358
# Rejected: 	0
# Iteration: 	3 / 1000
# Confirmed: 	0
# Tentative: 	3358
# Rejected: 	0
# Iteration: 	4 / 1000
# Confirmed: 	0
# Tentative: 	3358
# Rejected: 	0
# Iteration: 	5 / 1000
# Confirmed: 	0
# Tentative: 	3358
# Rejected: 	0
# Iteration: 	6 / 1000
# Confirmed: 	0
# Tentative: 	3358
# Rejected: 	0
# Iteration: 	7 / 1000
# Confirmed: 	0
# Tentative: 	3358
# Rejected: 	0
# Iteration: 	8 / 1000
# Confirmed: 	0
# Tentative: 	70
# Rejected: 	3288
# Iteration: 	9 / 1000
# Confirmed: 	0
# Tentative: 	70
# Rejected: 	3288
# Iteration: 	10 / 1000
# Confirmed: 	0
# Tentative: 	70
# Rejected: 	3288
# Iteration: 	11 / 1000
# Confirmed: 	0
# Tentative: 	70
# Rejected: 	3288
# Iteration: 	12 / 1000
# Confirmed: 	0
# Tentative: 	48
# Rejected: 	3310
# Iteration: 	13 / 1000
# Confirmed: 	0
# Tentative: 	48
# Rejected: 	3310
# Iteration: 	14 / 1000
# Confirmed: 	0
# Tentative: 	48
# Rejected: 	3310
# Iteration: 	15 / 1000
# Confirmed: 	0
# Tentative: 	48
# Rejected: 	3310
# Iteration: 	16 / 1000
# Confirmed: 	0
# Tentative: 	42
# Rejected: 	3316
# Iteration: 	17 / 1000
# Confirmed: 	0
# Tentative: 	42
# Rejected: 	3316
# Iteration: 	18 / 1000
# Confirmed: 	0
# Tentative: 	42
# Rejected: 	3316
# Iteration: 	19 / 1000
# Confirmed: 	0
# Tentative: 	38
# Rejected: 	3320
# Iteration: 	20 / 1000
# Confirmed: 	0
# Tentative: 	38
# Rejected: 	3320
# Iteration: 	21 / 1000
# Confirmed: 	0
# Tentative: 	38
# Rejected: 	3320
# Iteration: 	22 / 1000
# Confirmed: 	0
# Tentative: 	35
# Rejected: 	3323
# Iteration: 	23 / 1000
# Confirmed: 	0
# Tentative: 	35
# Rejected: 	3323
# Iteration: 	24 / 1000
# Confirmed: 	0
# Tentative: 	35
# Rejected: 	3323
# Iteration: 	25 / 1000
# Confirmed: 	0
# Tentative: 	35
# Rejected: 	3323
# Iteration: 	26 / 1000
# Confirmed: 	0
# Tentative: 	31
# Rejected: 	3327
# Iteration: 	27 / 1000
# Confirmed: 	0
# Tentative: 	31
# Rejected: 	3327
# Iteration: 	28 / 1000
# Confirmed: 	0
# Tentative: 	31
# Rejected: 	3327
# Iteration: 	29 / 1000
# Confirmed: 	0
# Tentative: 	30
# Rejected: 	3328
# Iteration: 	30 / 1000
# Confirmed: 	0
# Tentative: 	30
# Rejected: 	3328
# Iteration: 	31 / 1000
# Confirmed: 	0
# Tentative: 	30
# Rejected: 	3328
# Iteration: 	32 / 1000
# Confirmed: 	0
# Tentative: 	29
# Rejected: 	3329
# Iteration: 	33 / 1000
# Confirmed: 	0
# Tentative: 	29
# Rejected: 	3329
# Iteration: 	34 / 1000
# Confirmed: 	1
# Tentative: 	28
# Rejected: 	3329
# Iteration: 	35 / 1000
# Confirmed: 	1
# Tentative: 	28
# Rejected: 	3329
# Iteration: 	36 / 1000
# Confirmed: 	1
# Tentative: 	28
# Rejected: 	3329
# Iteration: 	37 / 1000
# Confirmed: 	1
# Tentative: 	28
# Rejected: 	3329
# Iteration: 	38 / 1000
# Confirmed: 	1
# Tentative: 	28
# Rejected: 	3329
# Iteration: 	39 / 1000
# Confirmed: 	1
# Tentative: 	28
# Rejected: 	3329
# Iteration: 	40 / 1000
# Confirmed: 	1
# Tentative: 	28
# Rejected: 	3329
# Iteration: 	41 / 1000
# Confirmed: 	1
# Tentative: 	28
# Rejected: 	3329
# Iteration: 	42 / 1000
# Confirmed: 	1
# Tentative: 	28
# Rejected: 	3329
# Iteration: 	43 / 1000
# Confirmed: 	1
# Tentative: 	28
# Rejected: 	3329
# Iteration: 	44 / 1000
# Confirmed: 	1
# Tentative: 	28
# Rejected: 	3329
# Iteration: 	45 / 1000
# Confirmed: 	1
# Tentative: 	28
# Rejected: 	3329
# Iteration: 	46 / 1000
# Confirmed: 	1
# Tentative: 	28
# Rejected: 	3329
# Iteration: 	47 / 1000
# Confirmed: 	1
# Tentative: 	28
# Rejected: 	3329
# Iteration: 	48 / 1000
# Confirmed: 	1
# Tentative: 	28
# Rejected: 	3329
# Iteration: 	49 / 1000
# Confirmed: 	1
# Tentative: 	28
# Rejected: 	3329
# Iteration: 	50 / 1000
# Confirmed: 	1
# Tentative: 	28
# Rejected: 	3329
# Iteration: 	51 / 1000
# Confirmed: 	1
# Tentative: 	27
# Rejected: 	3330
# Iteration: 	52 / 1000
# Confirmed: 	1
# Tentative: 	27
# Rejected: 	3330
# Iteration: 	53 / 1000
# Confirmed: 	1
# Tentative: 	27
# Rejected: 	3330
# Iteration: 	54 / 1000
# Confirmed: 	2
# Tentative: 	26
# Rejected: 	3330
# Iteration: 	55 / 1000
# Confirmed: 	2
# Tentative: 	26
# Rejected: 	3330
# Iteration: 	56 / 1000
# Confirmed: 	2
# Tentative: 	26
# Rejected: 	3330
# Iteration: 	57 / 1000
# Confirmed: 	3
# Tentative: 	25
# Rejected: 	3330
# Iteration: 	58 / 1000
# Confirmed: 	3
# Tentative: 	25
# Rejected: 	3330
# Iteration: 	59 / 1000
# Confirmed: 	5
# Tentative: 	23
# Rejected: 	3330
# Iteration: 	60 / 1000
# Confirmed: 	5
# Tentative: 	23
# Rejected: 	3330
# Iteration: 	61 / 1000
# Confirmed: 	5
# Tentative: 	23
# Rejected: 	3330
# Iteration: 	62 / 1000
# Confirmed: 	5
# Tentative: 	23
# Rejected: 	3330
# Iteration: 	63 / 1000
# Confirmed: 	5
# Tentative: 	23
# Rejected: 	3330
# Iteration: 	64 / 1000
# Confirmed: 	5
# Tentative: 	23
# Rejected: 	3330
# Iteration: 	65 / 1000
# Confirmed: 	5
# Tentative: 	23
# Rejected: 	3330
# Iteration: 	66 / 1000
# Confirmed: 	5
# Tentative: 	23
# Rejected: 	3330
# Iteration: 	67 / 1000
# Confirmed: 	5
# Tentative: 	23
# Rejected: 	3330
# Iteration: 	68 / 1000
# Confirmed: 	5
# Tentative: 	23
# Rejected: 	3330
# Iteration: 	69 / 1000
# Confirmed: 	5
# Tentative: 	23
# Rejected: 	3330
# Iteration: 	70 / 1000
# Confirmed: 	5
# Tentative: 	23
# Rejected: 	3330
# Iteration: 	71 / 1000
# Confirmed: 	5
# Tentative: 	23
# Rejected: 	3330
# Iteration: 	72 / 1000
# Confirmed: 	5
# Tentative: 	23
# Rejected: 	3330
# Iteration: 	73 / 1000
# Confirmed: 	5
# Tentative: 	23
# Rejected: 	3330
# Iteration: 	74 / 1000
# Confirmed: 	5
# Tentative: 	23
# Rejected: 	3330
# Iteration: 	75 / 1000
# Confirmed: 	5
# Tentative: 	23
# Rejected: 	3330
# Iteration: 	76 / 1000
# Confirmed: 	5
# Tentative: 	23
# Rejected: 	3330
# Iteration: 	77 / 1000
# Confirmed: 	5
# Tentative: 	23
# Rejected: 	3330
# Iteration: 	78 / 1000
# Confirmed: 	5
# Tentative: 	23
# Rejected: 	3330
# Iteration: 	79 / 1000
# Confirmed: 	5
# Tentative: 	23
# Rejected: 	3330
# Iteration: 	80 / 1000
# Confirmed: 	5
# Tentative: 	23
# Rejected: 	3330
# Iteration: 	81 / 1000
# Confirmed: 	5
# Tentative: 	23
# Rejected: 	3330
# Iteration: 	82 / 1000
# Confirmed: 	5
# Tentative: 	23
# Rejected: 	3330
# Iteration: 	83 / 1000
# Confirmed: 	5
# Tentative: 	23
# Rejected: 	3330
# Iteration: 	84 / 1000
# Confirmed: 	5
# Tentative: 	23
# Rejected: 	3330
# Iteration: 	85 / 1000
# Confirmed: 	6
# Tentative: 	22
# Rejected: 	3330
# Iteration: 	86 / 1000
# Confirmed: 	6
# Tentative: 	22
# Rejected: 	3330
# Iteration: 	87 / 1000
# Confirmed: 	6
# Tentative: 	22
# Rejected: 	3330
# Iteration: 	88 / 1000
# Confirmed: 	6
# Tentative: 	22
# Rejected: 	3330
# Iteration: 	89 / 1000
# Confirmed: 	6
# Tentative: 	22
# Rejected: 	3330
# Iteration: 	90 / 1000
# Confirmed: 	7
# Tentative: 	21
# Rejected: 	3330
# Iteration: 	91 / 1000
# Confirmed: 	7
# Tentative: 	21
# Rejected: 	3330
# Iteration: 	92 / 1000
# Confirmed: 	7
# Tentative: 	21
# Rejected: 	3330
# Iteration: 	93 / 1000
# Confirmed: 	7
# Tentative: 	20
# Rejected: 	3331
# Iteration: 	94 / 1000
# Confirmed: 	7
# Tentative: 	20
# Rejected: 	3331
# Iteration: 	95 / 1000
# Confirmed: 	7
# Tentative: 	20
# Rejected: 	3331
# Iteration: 	96 / 1000
# Confirmed: 	7
# Tentative: 	20
# Rejected: 	3331
# Iteration: 	97 / 1000
# Confirmed: 	7
# Tentative: 	20
# Rejected: 	3331
# Iteration: 	98 / 1000
# Confirmed: 	7
# Tentative: 	20
# Rejected: 	3331
# Iteration: 	99 / 1000
# Confirmed: 	7
# Tentative: 	20
# Rejected: 	3331
# Iteration: 	100 / 1000
# Confirmed: 	7
# Tentative: 	20
# Rejected: 	3331
# Iteration: 	101 / 1000
# Confirmed: 	7
# Tentative: 	20
# Rejected: 	3331
# Iteration: 	102 / 1000
# Confirmed: 	7
# Tentative: 	20
# Rejected: 	3331
# Iteration: 	103 / 1000
# Confirmed: 	7
# Tentative: 	20
# Rejected: 	3331
# Iteration: 	104 / 1000
# Confirmed: 	7
# Tentative: 	20
# Rejected: 	3331
# Iteration: 	105 / 1000
# Confirmed: 	7
# Tentative: 	20
# Rejected: 	3331
# Iteration: 	106 / 1000
# Confirmed: 	7
# Tentative: 	20
# Rejected: 	3331
# Iteration: 	107 / 1000
# Confirmed: 	7
# Tentative: 	20
# Rejected: 	3331
# Iteration: 	108 / 1000
# Confirmed: 	7
# Tentative: 	20
# Rejected: 	3331
# Iteration: 	109 / 1000
# Confirmed: 	7
# Tentative: 	20
# Rejected: 	3331
# Iteration: 	110 / 1000
# Confirmed: 	7
# Tentative: 	20
# Rejected: 	3331
# Iteration: 	111 / 1000
# Confirmed: 	7
# Tentative: 	20
# Rejected: 	3331
# Iteration: 	112 / 1000
# Confirmed: 	8
# Tentative: 	19
# Rejected: 	3331
# Iteration: 	113 / 1000
# Confirmed: 	8
# Tentative: 	19
# Rejected: 	3331
# Iteration: 	114 / 1000
# Confirmed: 	8
# Tentative: 	19
# Rejected: 	3331
# Iteration: 	115 / 1000
# Confirmed: 	8
# Tentative: 	19
# Rejected: 	3331
# Iteration: 	116 / 1000
# Confirmed: 	8
# Tentative: 	19
# Rejected: 	3331
# Iteration: 	117 / 1000
# Confirmed: 	8
# Tentative: 	19
# Rejected: 	3331
# Iteration: 	118 / 1000
# Confirmed: 	8
# Tentative: 	19
# Rejected: 	3331
# Iteration: 	119 / 1000
# Confirmed: 	8
# Tentative: 	19
# Rejected: 	3331
# Iteration: 	120 / 1000
# Confirmed: 	8
# Tentative: 	19
# Rejected: 	3331
# Iteration: 	121 / 1000
# Confirmed: 	8
# Tentative: 	19
# Rejected: 	3331
# Iteration: 	122 / 1000
# Confirmed: 	9
# Tentative: 	18
# Rejected: 	3331
# Iteration: 	123 / 1000
# Confirmed: 	9
# Tentative: 	18
# Rejected: 	3331
# Iteration: 	124 / 1000
# Confirmed: 	9
# Tentative: 	18
# Rejected: 	3331
# Iteration: 	125 / 1000
# Confirmed: 	9
# Tentative: 	18
# Rejected: 	3331
# Iteration: 	126 / 1000
# Confirmed: 	9
# Tentative: 	18
# Rejected: 	3331
# Iteration: 	127 / 1000
# Confirmed: 	9
# Tentative: 	18
# Rejected: 	3331
# Iteration: 	128 / 1000
# Confirmed: 	9
# Tentative: 	18
# Rejected: 	3331
# Iteration: 	129 / 1000
# Confirmed: 	9
# Tentative: 	18
# Rejected: 	3331
# Iteration: 	130 / 1000
# Confirmed: 	9
# Tentative: 	18
# Rejected: 	3331
# Iteration: 	131 / 1000
# Confirmed: 	9
# Tentative: 	18
# Rejected: 	3331
# Iteration: 	132 / 1000
# Confirmed: 	9
# Tentative: 	18
# Rejected: 	3331
# Iteration: 	133 / 1000
# Confirmed: 	9
# Tentative: 	18
# Rejected: 	3331
# Iteration: 	134 / 1000
# Confirmed: 	10
# Tentative: 	17
# Rejected: 	3331
# Iteration: 	135 / 1000
# Confirmed: 	10
# Tentative: 	17
# Rejected: 	3331
# Iteration: 	136 / 1000
# Confirmed: 	10
# Tentative: 	17
# Rejected: 	3331
# Iteration: 	137 / 1000
# Confirmed: 	10
# Tentative: 	17
# Rejected: 	3331
# Iteration: 	138 / 1000
# Confirmed: 	10
# Tentative: 	17
# Rejected: 	3331
# Iteration: 	139 / 1000
# Confirmed: 	10
# Tentative: 	17
# Rejected: 	3331
# Iteration: 	140 / 1000
# Confirmed: 	10
# Tentative: 	17
# Rejected: 	3331
# Iteration: 	141 / 1000
# Confirmed: 	11
# Tentative: 	16
# Rejected: 	3331
# Iteration: 	142 / 1000
# Confirmed: 	11
# Tentative: 	16
# Rejected: 	3331
# Iteration: 	143 / 1000
# Confirmed: 	11
# Tentative: 	16
# Rejected: 	3331
# Iteration: 	144 / 1000
# Confirmed: 	11
# Tentative: 	16
# Rejected: 	3331
# Iteration: 	145 / 1000
# Confirmed: 	11
# Tentative: 	16
# Rejected: 	3331
# Iteration: 	146 / 1000
# Confirmed: 	11
# Tentative: 	16
# Rejected: 	3331
# Iteration: 	147 / 1000
# Confirmed: 	11
# Tentative: 	16
# Rejected: 	3331
# Iteration: 	148 / 1000
# Confirmed: 	11
# Tentative: 	16
# Rejected: 	3331
# Iteration: 	149 / 1000
# Confirmed: 	12
# Tentative: 	15
# Rejected: 	3331
# Iteration: 	150 / 1000
# Confirmed: 	12
# Tentative: 	15
# Rejected: 	3331
# Iteration: 	151 / 1000
# Confirmed: 	12
# Tentative: 	15
# Rejected: 	3331
# Iteration: 	152 / 1000
# Confirmed: 	12
# Tentative: 	15
# Rejected: 	3331
# Iteration: 	153 / 1000
# Confirmed: 	13
# Tentative: 	14
# Rejected: 	3331
# Iteration: 	154 / 1000
# Confirmed: 	13
# Tentative: 	14
# Rejected: 	3331
# Iteration: 	155 / 1000
# Confirmed: 	13
# Tentative: 	14
# Rejected: 	3331
# Iteration: 	156 / 1000
# Confirmed: 	13
# Tentative: 	14
# Rejected: 	3331
# Iteration: 	157 / 1000
# Confirmed: 	13
# Tentative: 	14
# Rejected: 	3331
# Iteration: 	158 / 1000
# Confirmed: 	13
# Tentative: 	14
# Rejected: 	3331
# Iteration: 	159 / 1000
# Confirmed: 	13
# Tentative: 	14
# Rejected: 	3331
# Iteration: 	160 / 1000
# Confirmed: 	13
# Tentative: 	14
# Rejected: 	3331
# Iteration: 	161 / 1000
# Confirmed: 	13
# Tentative: 	14
# Rejected: 	3331
# Iteration: 	162 / 1000
# Confirmed: 	13
# Tentative: 	14
# Rejected: 	3331
# Iteration: 	163 / 1000
# Confirmed: 	14
# Tentative: 	13
# Rejected: 	3331
# Iteration: 	164 / 1000
# Confirmed: 	14
# Tentative: 	13
# Rejected: 	3331
# Iteration: 	165 / 1000
# Confirmed: 	14
# Tentative: 	13
# Rejected: 	3331
# Iteration: 	166 / 1000
# Confirmed: 	14
# Tentative: 	13
# Rejected: 	3331
# Iteration: 	167 / 1000
# Confirmed: 	14
# Tentative: 	13
# Rejected: 	3331
# Iteration: 	168 / 1000
# Confirmed: 	15
# Tentative: 	12
# Rejected: 	3331
# Iteration: 	169 / 1000
# Confirmed: 	15
# Tentative: 	12
# Rejected: 	3331
# Iteration: 	170 / 1000
# Confirmed: 	15
# Tentative: 	12
# Rejected: 	3331
# Iteration: 	171 / 1000
# Confirmed: 	15
# Tentative: 	12
# Rejected: 	3331
# Iteration: 	172 / 1000
# Confirmed: 	15
# Tentative: 	12
# Rejected: 	3331
# Iteration: 	173 / 1000
# Confirmed: 	15
# Tentative: 	12
# Rejected: 	3331
# Iteration: 	174 / 1000
# Confirmed: 	15
# Tentative: 	12
# Rejected: 	3331
# Iteration: 	175 / 1000
# Confirmed: 	15
# Tentative: 	12
# Rejected: 	3331
# Iteration: 	176 / 1000
# Confirmed: 	15
# Tentative: 	12
# Rejected: 	3331
# Iteration: 	177 / 1000
# Confirmed: 	15
# Tentative: 	12
# Rejected: 	3331
# Iteration: 	178 / 1000
# Confirmed: 	15
# Tentative: 	12
# Rejected: 	3331
# Iteration: 	179 / 1000
# Confirmed: 	15
# Tentative: 	12
# Rejected: 	3331
# Iteration: 	180 / 1000
# Confirmed: 	15
# Tentative: 	12
# Rejected: 	3331
# Iteration: 	181 / 1000
# Confirmed: 	15
# Tentative: 	12
# Rejected: 	3331
# Iteration: 	182 / 1000
# Confirmed: 	15
# Tentative: 	12
# Rejected: 	3331
# Iteration: 	183 / 1000
# Confirmed: 	15
# Tentative: 	12
# Rejected: 	3331
# Iteration: 	184 / 1000
# Confirmed: 	15
# Tentative: 	12
# Rejected: 	3331
# Iteration: 	185 / 1000
# Confirmed: 	15
# Tentative: 	12
# Rejected: 	3331
# Iteration: 	186 / 1000
# Confirmed: 	15
# Tentative: 	12
# Rejected: 	3331
# Iteration: 	187 / 1000
# Confirmed: 	15
# Tentative: 	12
# Rejected: 	3331
# Iteration: 	188 / 1000
# Confirmed: 	15
# Tentative: 	12
# Rejected: 	3331
# Iteration: 	189 / 1000
# Confirmed: 	15
# Tentative: 	12
# Rejected: 	3331
# Iteration: 	190 / 1000
# Confirmed: 	15
# Tentative: 	12
# Rejected: 	3331
# Iteration: 	191 / 1000
# Confirmed: 	15
# Tentative: 	12
# Rejected: 	3331
# Iteration: 	192 / 1000
# Confirmed: 	15
# Tentative: 	12
# Rejected: 	3331
# Iteration: 	193 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	194 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	195 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	196 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	197 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	198 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	199 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	200 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	201 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	202 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	203 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	204 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	205 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	206 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	207 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	208 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	209 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	210 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	211 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	212 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	213 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	214 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	215 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	216 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	217 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	218 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	219 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	220 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	221 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	222 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	223 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	224 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	225 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	226 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	227 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	228 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	229 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	230 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	231 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	232 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	233 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	234 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	235 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	236 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	237 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	238 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	239 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	240 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	241 / 1000
# Confirmed: 	16
# Tentative: 	11
# Rejected: 	3331
# Iteration: 	242 / 1000
# Confirmed: 	17
# Tentative: 	10
# Rejected: 	3331
# Iteration: 	243 / 1000
# Confirmed: 	17
# Tentative: 	10
# Rejected: 	3331
# Iteration: 	244 / 1000
# Confirmed: 	17
# Tentative: 	10
# Rejected: 	3331
# Iteration: 	245 / 1000
# Confirmed: 	17
# Tentative: 	10
# Rejected: 	3331
# Iteration: 	246 / 1000
# Confirmed: 	17
# Tentative: 	10
# Rejected: 	3331
# Iteration: 	247 / 1000
# Confirmed: 	17
# Tentative: 	10
# Rejected: 	3331
# Iteration: 	248 / 1000
# Confirmed: 	17
# Tentative: 	10
# Rejected: 	3331
# Iteration: 	249 / 1000
# Confirmed: 	17
# Tentative: 	10
# Rejected: 	3331
# Iteration: 	250 / 1000
# Confirmed: 	17
# Tentative: 	10
# Rejected: 	3331
# Iteration: 	251 / 1000
# Confirmed: 	17
# Tentative: 	10
# Rejected: 	3331
# Iteration: 	252 / 1000
# Confirmed: 	17
# Tentative: 	10
# Rejected: 	3331
# Iteration: 	253 / 1000
# Confirmed: 	17
# Tentative: 	10
# Rejected: 	3331
# Iteration: 	254 / 1000
# Confirmed: 	17
# Tentative: 	10
# Rejected: 	3331
# Iteration: 	255 / 1000
# Confirmed: 	17
# Tentative: 	10
# Rejected: 	3331
# Iteration: 	256 / 1000
# Confirmed: 	17
# Tentative: 	10
# Rejected: 	3331
# Iteration: 	257 / 1000
# Confirmed: 	17
# Tentative: 	10
# Rejected: 	3331
# Iteration: 	258 / 1000
# Confirmed: 	17
# Tentative: 	10
# Rejected: 	3331
# Iteration: 	259 / 1000
# Confirmed: 	17
# Tentative: 	10
# Rejected: 	3331
# Iteration: 	260 / 1000
# Confirmed: 	17
# Tentative: 	10
# Rejected: 	3331
# Iteration: 	261 / 1000
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	3331
# Iteration: 	262 / 1000
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	3331
# Iteration: 	263 / 1000
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	3331
# Iteration: 	264 / 1000
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	3331
# Iteration: 	265 / 1000
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	3331
# Iteration: 	266 / 1000
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	3331
# Iteration: 	267 / 1000
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	3331
# Iteration: 	268 / 1000
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	3331
# Iteration: 	269 / 1000
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	3331
# Iteration: 	270 / 1000
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	3331
# Iteration: 	271 / 1000
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	3331
# Iteration: 	272 / 1000
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	3331
# Iteration: 	273 / 1000
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	3331
# Iteration: 	274 / 1000
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	3331
# Iteration: 	275 / 1000
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	3331
# Iteration: 	276 / 1000
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	3331
# Iteration: 	277 / 1000
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	3331
# Iteration: 	278 / 1000
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	3331
# Iteration: 	279 / 1000
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	3331
# Iteration: 	280 / 1000
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	3331
# Iteration: 	281 / 1000
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	3331
# Iteration: 	282 / 1000
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	3331
# Iteration: 	283 / 1000
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	3331
# Iteration: 	284 / 1000
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	3331
# Iteration: 	285 / 1000
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	3331
# Iteration: 	286 / 1000
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	3331
# Iteration: 	287 / 1000
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	3331
# Iteration: 	288 / 1000
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	3331
# Iteration: 	289 / 1000
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	3331
# Iteration: 	290 / 1000
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	3331
# Iteration: 	291 / 1000
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	3331
# Iteration: 	292 / 1000
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	3331
# Iteration: 	293 / 1000
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	3331
# Iteration: 	294 / 1000
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	3331
# Iteration: 	295 / 1000
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	3331
# Iteration: 	296 / 1000
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	3331
# Iteration: 	297 / 1000
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	3331
# Iteration: 	298 / 1000
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	3331
# Iteration: 	299 / 1000
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	3331
# Iteration: 	300 / 1000
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	3331
# Iteration: 	301 / 1000
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	3331
# Iteration: 	302 / 1000
# Confirmed: 	19
# Tentative: 	8
# Rejected: 	3331
# Iteration: 	303 / 1000
# Confirmed: 	19
# Tentative: 	8
# Rejected: 	3331
# Iteration: 	304 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	305 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	306 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	307 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	308 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	309 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	310 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	311 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	312 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	313 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	314 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	315 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	316 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	317 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	318 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	319 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	320 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	321 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	322 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	323 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	324 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	325 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	326 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	327 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	328 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	329 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	330 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	331 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	332 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	333 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	334 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	335 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	336 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	337 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	338 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	339 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	340 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	341 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	342 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	343 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	344 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	345 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	346 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	347 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	348 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	349 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	350 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	351 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	352 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	353 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	354 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	355 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	356 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	357 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	358 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	359 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	360 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	361 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	362 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	363 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	364 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	365 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	366 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	367 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	368 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	369 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	370 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	371 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	372 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	373 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	374 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	375 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	376 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	377 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	378 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	379 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	380 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	381 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	382 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	383 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	384 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	385 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	386 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	387 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	388 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	389 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	390 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	391 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	392 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	393 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	394 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	395 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	396 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	397 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	398 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	399 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	400 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	401 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	402 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	403 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	404 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	405 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	406 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	407 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	408 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	409 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	410 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	411 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	412 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	413 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	414 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	415 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	416 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	417 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	418 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	419 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	420 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	421 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	422 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	423 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	424 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	425 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	426 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	427 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	428 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	429 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	430 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	431 / 1000
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	3331
# Iteration: 	432 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	433 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	434 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	435 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	436 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	437 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	438 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	439 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	440 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	441 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	442 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	443 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	444 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	445 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	446 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	447 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	448 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	449 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	450 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	451 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	452 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	453 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	454 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	455 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	456 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	457 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	458 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	459 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	460 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	461 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	462 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	463 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	464 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	465 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	466 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	467 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	468 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	469 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	470 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	471 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	472 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	473 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	474 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	475 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	476 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	477 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	478 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	479 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	480 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	481 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	482 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	483 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	484 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	485 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	486 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	487 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	488 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	489 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	490 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	491 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	492 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	493 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	494 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	495 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	496 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	497 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	498 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	499 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	500 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	501 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	502 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	503 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	504 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	505 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	506 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	507 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	508 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	509 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	510 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	511 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	512 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	513 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	514 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	515 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	516 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	517 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	518 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	519 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	520 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	521 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	522 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	523 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	524 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	525 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	526 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	527 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	528 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	529 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	530 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	531 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	532 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	533 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	534 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	535 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	536 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	537 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	538 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	539 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	540 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	541 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	542 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	543 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	544 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	545 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	546 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	547 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	548 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	549 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	550 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	551 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	552 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	553 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	554 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	555 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	556 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	557 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	558 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	559 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	560 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	561 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	562 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	563 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	564 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	565 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	566 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	567 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	568 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	569 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	570 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	571 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	572 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	573 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	574 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	575 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	576 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	577 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	578 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	579 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	580 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	581 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	582 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	583 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	584 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	585 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	586 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	587 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	588 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	589 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	590 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	591 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	592 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	593 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	594 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	595 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	596 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	597 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	598 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	599 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	600 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	601 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	602 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	603 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	604 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	605 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	606 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	607 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	608 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	609 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	610 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	611 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	612 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	613 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	614 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	615 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	616 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	617 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	618 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	619 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	620 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	621 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	622 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	623 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	624 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	625 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	626 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	627 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	628 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	629 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	630 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	631 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	632 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	633 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	634 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	635 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	636 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	637 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	638 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	639 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	640 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	641 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	642 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	643 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	644 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	645 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	646 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	647 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	648 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	649 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	650 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	651 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	652 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	653 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	654 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	655 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	656 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	657 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	658 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	659 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	660 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	661 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	662 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	663 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	664 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	665 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	666 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	667 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	668 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	669 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	670 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	671 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	672 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	673 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	674 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	675 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	676 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	677 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	678 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	679 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	680 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	681 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	682 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	683 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	684 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	685 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	686 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	687 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	688 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	689 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	690 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	691 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	692 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	693 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	694 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	695 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	696 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	697 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	698 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	699 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	700 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	701 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	702 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	703 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	704 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	705 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	706 / 1000
# Confirmed: 	21
# ...
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	767 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	768 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	769 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	770 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	771 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	772 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	773 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	774 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	775 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	776 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	777 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	778 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	779 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	780 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	781 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	782 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	783 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	784 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	785 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	786 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	787 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	788 / 1000
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	3331
# Iteration: 	789 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	790 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	791 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	792 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	793 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	794 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	795 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	796 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	797 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	798 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	799 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	800 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	801 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	802 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	803 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	804 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	805 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	806 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	807 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	808 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	809 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	810 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	811 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	812 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	813 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	814 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	815 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	816 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	817 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	818 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	819 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	820 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	821 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	822 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	823 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	824 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	825 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	826 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	827 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	828 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	829 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	830 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	831 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	832 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	833 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	834 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	835 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	836 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	837 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	838 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	839 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	840 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	841 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	842 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	843 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	844 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	845 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	846 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	847 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	848 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	849 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	850 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	851 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	852 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	853 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	854 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	855 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	856 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	857 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	858 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	859 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	860 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	861 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	862 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	863 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	864 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	865 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	866 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	867 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	868 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	869 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	870 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	871 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	872 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	873 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	874 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	875 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	876 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	877 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	878 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	879 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	880 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	881 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	882 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	883 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	884 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	885 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	886 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	887 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	888 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	889 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	890 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	891 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	892 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	893 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	894 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	895 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	896 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	897 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	898 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	899 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	900 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	901 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	902 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	903 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	904 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	905 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	906 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	907 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	908 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	909 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	910 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	911 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	912 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	913 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	914 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	915 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	916 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	917 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	918 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	919 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	920 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	921 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	922 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	923 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	924 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	925 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	926 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	927 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	928 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	929 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	930 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	931 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	932 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	933 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	934 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	935 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	936 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	937 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	938 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	939 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	940 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	941 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	942 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	943 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	944 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	945 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	946 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	947 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	948 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	949 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	950 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	951 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	952 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	953 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	954 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	955 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	956 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	957 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	958 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	959 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	960 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	961 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	962 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	963 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	964 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	965 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	966 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	967 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	968 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	969 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	970 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	971 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	972 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	973 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	974 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	975 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	976 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	977 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	978 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	979 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	980 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	981 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	982 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	983 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	984 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	985 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	986 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	987 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	988 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	989 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	990 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	991 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	992 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	993 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	994 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	995 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	996 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	997 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	998 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
# Iteration: 	999 / 1000
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3331
#
#
# BorutaPy finished running.
#
# Iteration: 	1000 / 1000
# Confirmed: 	22
# Tentative: 	3
# Rejected: 	3333

# %%
selected_features_ps = GeneSelection(best_rf_ps,feat_ps,target_numeric_ps)
# Out:
# Iteration: 	1 / 1000
# Confirmed: 	0
# Tentative: 	420
# Rejected: 	0
# Iteration: 	2 / 1000
# Confirmed: 	0
# Tentative: 	420
# Rejected: 	0
# Iteration: 	3 / 1000
# Confirmed: 	0
# Tentative: 	420
# Rejected: 	0
# Iteration: 	4 / 1000
# Confirmed: 	0
# Tentative: 	420
# Rejected: 	0
# Iteration: 	5 / 1000
# Confirmed: 	0
# Tentative: 	420
# Rejected: 	0
# Iteration: 	6 / 1000
# Confirmed: 	0
# Tentative: 	420
# Rejected: 	0
# Iteration: 	7 / 1000
# Confirmed: 	0
# Tentative: 	420
# Rejected: 	0
# Iteration: 	8 / 1000
# Confirmed: 	0
# Tentative: 	59
# Rejected: 	361
# Iteration: 	9 / 1000
# Confirmed: 	0
# Tentative: 	59
# Rejected: 	361
# Iteration: 	10 / 1000
# Confirmed: 	0
# Tentative: 	59
# Rejected: 	361
# Iteration: 	11 / 1000
# Confirmed: 	0
# Tentative: 	59
# Rejected: 	361
# Iteration: 	12 / 1000
# Confirmed: 	0
# Tentative: 	45
# Rejected: 	375
# Iteration: 	13 / 1000
# Confirmed: 	2
# Tentative: 	43
# Rejected: 	375
# Iteration: 	14 / 1000
# Confirmed: 	2
# Tentative: 	43
# Rejected: 	375
# Iteration: 	15 / 1000
# Confirmed: 	2
# Tentative: 	43
# Rejected: 	375
# Iteration: 	16 / 1000
# Confirmed: 	3
# Tentative: 	39
# Rejected: 	378
# Iteration: 	17 / 1000
# Confirmed: 	3
# Tentative: 	39
# Rejected: 	378
# Iteration: 	18 / 1000
# Confirmed: 	3
# Tentative: 	39
# Rejected: 	378
# Iteration: 	19 / 1000
# Confirmed: 	3
# Tentative: 	37
# Rejected: 	380
# Iteration: 	20 / 1000
# Confirmed: 	3
# Tentative: 	37
# Rejected: 	380
# Iteration: 	21 / 1000
# Confirmed: 	3
# Tentative: 	37
# Rejected: 	380
# Iteration: 	22 / 1000
# Confirmed: 	3
# Tentative: 	34
# Rejected: 	383
# Iteration: 	23 / 1000
# Confirmed: 	3
# Tentative: 	34
# Rejected: 	383
# Iteration: 	24 / 1000
# Confirmed: 	3
# Tentative: 	34
# Rejected: 	383
# Iteration: 	25 / 1000
# Confirmed: 	3
# Tentative: 	34
# Rejected: 	383
# Iteration: 	26 / 1000
# Confirmed: 	4
# Tentative: 	31
# Rejected: 	385
# Iteration: 	27 / 1000
# Confirmed: 	4
# Tentative: 	31
# Rejected: 	385
# Iteration: 	28 / 1000
# Confirmed: 	4
# Tentative: 	31
# Rejected: 	385
# Iteration: 	29 / 1000
# Confirmed: 	4
# Tentative: 	30
# Rejected: 	386
# Iteration: 	30 / 1000
# Confirmed: 	4
# Tentative: 	30
# Rejected: 	386
# Iteration: 	31 / 1000
# Confirmed: 	4
# Tentative: 	30
# Rejected: 	386
# Iteration: 	32 / 1000
# Confirmed: 	4
# Tentative: 	30
# Rejected: 	386
# Iteration: 	33 / 1000
# Confirmed: 	4
# Tentative: 	30
# Rejected: 	386
# Iteration: 	34 / 1000
# Confirmed: 	7
# Tentative: 	25
# Rejected: 	388
# Iteration: 	35 / 1000
# Confirmed: 	7
# Tentative: 	25
# Rejected: 	388
# Iteration: 	36 / 1000
# Confirmed: 	7
# Tentative: 	25
# Rejected: 	388
# Iteration: 	37 / 1000
# Confirmed: 	7
# Tentative: 	24
# Rejected: 	389
# Iteration: 	38 / 1000
# Confirmed: 	7
# Tentative: 	24
# Rejected: 	389
# Iteration: 	39 / 1000
# Confirmed: 	7
# Tentative: 	24
# Rejected: 	389
# Iteration: 	40 / 1000
# Confirmed: 	7
# Tentative: 	24
# Rejected: 	389
# Iteration: 	41 / 1000
# Confirmed: 	7
# Tentative: 	24
# Rejected: 	389
# Iteration: 	42 / 1000
# Confirmed: 	7
# Tentative: 	24
# Rejected: 	389
# Iteration: 	43 / 1000
# Confirmed: 	7
# Tentative: 	24
# Rejected: 	389
# Iteration: 	44 / 1000
# Confirmed: 	7
# Tentative: 	24
# Rejected: 	389
# Iteration: 	45 / 1000
# Confirmed: 	7
# Tentative: 	24
# Rejected: 	389
# Iteration: 	46 / 1000
# Confirmed: 	7
# Tentative: 	24
# Rejected: 	389
# Iteration: 	47 / 1000
# Confirmed: 	7
# Tentative: 	24
# Rejected: 	389
# Iteration: 	48 / 1000
# Confirmed: 	7
# Tentative: 	24
# Rejected: 	389
# Iteration: 	49 / 1000
# Confirmed: 	7
# Tentative: 	23
# Rejected: 	390
# Iteration: 	50 / 1000
# Confirmed: 	7
# Tentative: 	23
# Rejected: 	390
# Iteration: 	51 / 1000
# Confirmed: 	7
# Tentative: 	23
# Rejected: 	390
# Iteration: 	52 / 1000
# Confirmed: 	7
# Tentative: 	23
# Rejected: 	390
# Iteration: 	53 / 1000
# Confirmed: 	7
# Tentative: 	23
# Rejected: 	390
# Iteration: 	54 / 1000
# Confirmed: 	7
# Tentative: 	23
# Rejected: 	390
# Iteration: 	55 / 1000
# Confirmed: 	7
# Tentative: 	23
# Rejected: 	390
# Iteration: 	56 / 1000
# Confirmed: 	7
# Tentative: 	23
# Rejected: 	390
# Iteration: 	57 / 1000
# Confirmed: 	7
# Tentative: 	23
# Rejected: 	390
# Iteration: 	58 / 1000
# Confirmed: 	7
# Tentative: 	23
# Rejected: 	390
# Iteration: 	59 / 1000
# Confirmed: 	7
# Tentative: 	23
# Rejected: 	390
# Iteration: 	60 / 1000
# Confirmed: 	7
# Tentative: 	23
# Rejected: 	390
# Iteration: 	61 / 1000
# Confirmed: 	7
# Tentative: 	23
# Rejected: 	390
# Iteration: 	62 / 1000
# Confirmed: 	7
# Tentative: 	22
# Rejected: 	391
# Iteration: 	63 / 1000
# Confirmed: 	7
# Tentative: 	22
# Rejected: 	391
# Iteration: 	64 / 1000
# Confirmed: 	7
# Tentative: 	22
# Rejected: 	391
# Iteration: 	65 / 1000
# Confirmed: 	7
# Tentative: 	22
# Rejected: 	391
# Iteration: 	66 / 1000
# Confirmed: 	7
# Tentative: 	22
# Rejected: 	391
# Iteration: 	67 / 1000
# Confirmed: 	7
# Tentative: 	22
# Rejected: 	391
# Iteration: 	68 / 1000
# Confirmed: 	7
# Tentative: 	22
# Rejected: 	391
# Iteration: 	69 / 1000
# Confirmed: 	7
# Tentative: 	22
# Rejected: 	391
# Iteration: 	70 / 1000
# Confirmed: 	7
# Tentative: 	22
# Rejected: 	391
# Iteration: 	71 / 1000
# Confirmed: 	7
# Tentative: 	22
# Rejected: 	391
# Iteration: 	72 / 1000
# Confirmed: 	7
# Tentative: 	22
# Rejected: 	391
# Iteration: 	73 / 1000
# Confirmed: 	7
# Tentative: 	22
# Rejected: 	391
# Iteration: 	74 / 1000
# Confirmed: 	7
# Tentative: 	22
# Rejected: 	391
# Iteration: 	75 / 1000
# Confirmed: 	7
# Tentative: 	22
# Rejected: 	391
# Iteration: 	76 / 1000
# Confirmed: 	7
# Tentative: 	22
# Rejected: 	391
# Iteration: 	77 / 1000
# Confirmed: 	8
# Tentative: 	20
# Rejected: 	392
# Iteration: 	78 / 1000
# Confirmed: 	8
# Tentative: 	20
# Rejected: 	392
# Iteration: 	79 / 1000
# Confirmed: 	8
# Tentative: 	20
# Rejected: 	392
# Iteration: 	80 / 1000
# Confirmed: 	8
# Tentative: 	20
# Rejected: 	392
# Iteration: 	81 / 1000
# Confirmed: 	8
# Tentative: 	20
# Rejected: 	392
# Iteration: 	82 / 1000
# Confirmed: 	8
# Tentative: 	20
# Rejected: 	392
# Iteration: 	83 / 1000
# Confirmed: 	8
# Tentative: 	20
# Rejected: 	392
# Iteration: 	84 / 1000
# Confirmed: 	8
# Tentative: 	20
# Rejected: 	392
# Iteration: 	85 / 1000
# Confirmed: 	8
# Tentative: 	20
# Rejected: 	392
# Iteration: 	86 / 1000
# Confirmed: 	8
# Tentative: 	20
# Rejected: 	392
# Iteration: 	87 / 1000
# Confirmed: 	8
# Tentative: 	20
# Rejected: 	392
# Iteration: 	88 / 1000
# Confirmed: 	9
# Tentative: 	19
# Rejected: 	392
# Iteration: 	89 / 1000
# Confirmed: 	9
# Tentative: 	19
# Rejected: 	392
# Iteration: 	90 / 1000
# Confirmed: 	10
# Tentative: 	18
# Rejected: 	392
# Iteration: 	91 / 1000
# Confirmed: 	10
# Tentative: 	18
# Rejected: 	392
# Iteration: 	92 / 1000
# Confirmed: 	10
# Tentative: 	18
# Rejected: 	392
# Iteration: 	93 / 1000
# Confirmed: 	10
# Tentative: 	18
# Rejected: 	392
# Iteration: 	94 / 1000
# Confirmed: 	10
# Tentative: 	18
# Rejected: 	392
# Iteration: 	95 / 1000
# Confirmed: 	10
# Tentative: 	18
# Rejected: 	392
# Iteration: 	96 / 1000
# Confirmed: 	10
# Tentative: 	18
# Rejected: 	392
# Iteration: 	97 / 1000
# Confirmed: 	10
# Tentative: 	18
# Rejected: 	392
# Iteration: 	98 / 1000
# Confirmed: 	10
# Tentative: 	18
# Rejected: 	392
# Iteration: 	99 / 1000
# Confirmed: 	10
# Tentative: 	18
# Rejected: 	392
# Iteration: 	100 / 1000
# Confirmed: 	10
# Tentative: 	18
# Rejected: 	392
# Iteration: 	101 / 1000
# Confirmed: 	10
# Tentative: 	18
# Rejected: 	392
# Iteration: 	102 / 1000
# Confirmed: 	10
# Tentative: 	18
# Rejected: 	392
# Iteration: 	103 / 1000
# Confirmed: 	10
# Tentative: 	17
# Rejected: 	393
# Iteration: 	104 / 1000
# Confirmed: 	10
# Tentative: 	17
# Rejected: 	393
# Iteration: 	105 / 1000
# Confirmed: 	10
# Tentative: 	16
# Rejected: 	394
# Iteration: 	106 / 1000
# Confirmed: 	10
# Tentative: 	16
# Rejected: 	394
# Iteration: 	107 / 1000
# Confirmed: 	10
# Tentative: 	16
# Rejected: 	394
# Iteration: 	108 / 1000
# Confirmed: 	10
# Tentative: 	16
# Rejected: 	394
# Iteration: 	109 / 1000
# Confirmed: 	10
# Tentative: 	16
# Rejected: 	394
# Iteration: 	110 / 1000
# Confirmed: 	10
# Tentative: 	16
# Rejected: 	394
# Iteration: 	111 / 1000
# Confirmed: 	10
# Tentative: 	16
# Rejected: 	394
# Iteration: 	112 / 1000
# Confirmed: 	10
# Tentative: 	16
# Rejected: 	394
# Iteration: 	113 / 1000
# Confirmed: 	10
# Tentative: 	16
# Rejected: 	394
# Iteration: 	114 / 1000
# Confirmed: 	10
# Tentative: 	16
# Rejected: 	394
# Iteration: 	115 / 1000
# Confirmed: 	10
# Tentative: 	16
# Rejected: 	394
# Iteration: 	116 / 1000
# Confirmed: 	10
# Tentative: 	16
# Rejected: 	394
# Iteration: 	117 / 1000
# Confirmed: 	10
# Tentative: 	16
# Rejected: 	394
# Iteration: 	118 / 1000
# Confirmed: 	10
# Tentative: 	16
# Rejected: 	394
# Iteration: 	119 / 1000
# Confirmed: 	10
# Tentative: 	16
# Rejected: 	394
# Iteration: 	120 / 1000
# Confirmed: 	10
# Tentative: 	16
# Rejected: 	394
# Iteration: 	121 / 1000
# Confirmed: 	10
# Tentative: 	16
# Rejected: 	394
# Iteration: 	122 / 1000
# Confirmed: 	10
# Tentative: 	16
# Rejected: 	394
# Iteration: 	123 / 1000
# Confirmed: 	10
# Tentative: 	16
# Rejected: 	394
# Iteration: 	124 / 1000
# Confirmed: 	10
# Tentative: 	16
# Rejected: 	394
# Iteration: 	125 / 1000
# Confirmed: 	10
# Tentative: 	16
# Rejected: 	394
# Iteration: 	126 / 1000
# Confirmed: 	10
# Tentative: 	16
# Rejected: 	394
# Iteration: 	127 / 1000
# Confirmed: 	10
# Tentative: 	16
# Rejected: 	394
# Iteration: 	128 / 1000
# Confirmed: 	10
# Tentative: 	16
# Rejected: 	394
# Iteration: 	129 / 1000
# Confirmed: 	10
# Tentative: 	16
# Rejected: 	394
# Iteration: 	130 / 1000
# Confirmed: 	10
# Tentative: 	16
# Rejected: 	394
# Iteration: 	131 / 1000
# Confirmed: 	10
# Tentative: 	16
# Rejected: 	394
# Iteration: 	132 / 1000
# Confirmed: 	10
# Tentative: 	16
# Rejected: 	394
# Iteration: 	133 / 1000
# Confirmed: 	10
# Tentative: 	16
# Rejected: 	394
# Iteration: 	134 / 1000
# Confirmed: 	10
# Tentative: 	16
# Rejected: 	394
# Iteration: 	135 / 1000
# Confirmed: 	10
# Tentative: 	16
# Rejected: 	394
# Iteration: 	136 / 1000
# Confirmed: 	10
# Tentative: 	16
# Rejected: 	394
# Iteration: 	137 / 1000
# Confirmed: 	10
# Tentative: 	16
# Rejected: 	394
# Iteration: 	138 / 1000
# Confirmed: 	10
# Tentative: 	16
# Rejected: 	394
# Iteration: 	139 / 1000
# Confirmed: 	10
# Tentative: 	16
# Rejected: 	394
# Iteration: 	140 / 1000
# Confirmed: 	10
# Tentative: 	16
# Rejected: 	394
# Iteration: 	141 / 1000
# Confirmed: 	10
# Tentative: 	16
# Rejected: 	394
# Iteration: 	142 / 1000
# Confirmed: 	10
# Tentative: 	16
# Rejected: 	394
# Iteration: 	143 / 1000
# Confirmed: 	10
# Tentative: 	16
# Rejected: 	394
# Iteration: 	144 / 1000
# Confirmed: 	10
# Tentative: 	16
# Rejected: 	394
# Iteration: 	145 / 1000
# Confirmed: 	10
# Tentative: 	16
# Rejected: 	394
# Iteration: 	146 / 1000
# Confirmed: 	11
# Tentative: 	15
# Rejected: 	394
# Iteration: 	147 / 1000
# Confirmed: 	11
# Tentative: 	15
# Rejected: 	394
# Iteration: 	148 / 1000
# Confirmed: 	11
# Tentative: 	15
# Rejected: 	394
# Iteration: 	149 / 1000
# Confirmed: 	11
# Tentative: 	15
# Rejected: 	394
# Iteration: 	150 / 1000
# Confirmed: 	11
# Tentative: 	15
# Rejected: 	394
# Iteration: 	151 / 1000
# Confirmed: 	11
# Tentative: 	15
# Rejected: 	394
# Iteration: 	152 / 1000
# Confirmed: 	11
# Tentative: 	15
# Rejected: 	394
# Iteration: 	153 / 1000
# Confirmed: 	11
# Tentative: 	15
# Rejected: 	394
# Iteration: 	154 / 1000
# Confirmed: 	11
# Tentative: 	15
# Rejected: 	394
# Iteration: 	155 / 1000
# Confirmed: 	11
# Tentative: 	15
# Rejected: 	394
# Iteration: 	156 / 1000
# Confirmed: 	11
# Tentative: 	15
# Rejected: 	394
# Iteration: 	157 / 1000
# Confirmed: 	11
# Tentative: 	15
# Rejected: 	394
# Iteration: 	158 / 1000
# Confirmed: 	11
# Tentative: 	15
# Rejected: 	394
# Iteration: 	159 / 1000
# Confirmed: 	11
# Tentative: 	15
# Rejected: 	394
# Iteration: 	160 / 1000
# Confirmed: 	11
# Tentative: 	15
# Rejected: 	394
# Iteration: 	161 / 1000
# Confirmed: 	11
# Tentative: 	15
# Rejected: 	394
# Iteration: 	162 / 1000
# Confirmed: 	11
# Tentative: 	15
# Rejected: 	394
# Iteration: 	163 / 1000
# Confirmed: 	11
# Tentative: 	15
# Rejected: 	394
# Iteration: 	164 / 1000
# Confirmed: 	11
# Tentative: 	15
# Rejected: 	394
# Iteration: 	165 / 1000
# Confirmed: 	11
# Tentative: 	15
# Rejected: 	394
# Iteration: 	166 / 1000
# Confirmed: 	11
# Tentative: 	15
# Rejected: 	394
# Iteration: 	167 / 1000
# Confirmed: 	11
# Tentative: 	15
# Rejected: 	394
# Iteration: 	168 / 1000
# Confirmed: 	11
# Tentative: 	15
# Rejected: 	394
# Iteration: 	169 / 1000
# Confirmed: 	11
# Tentative: 	15
# Rejected: 	394
# Iteration: 	170 / 1000
# Confirmed: 	11
# Tentative: 	15
# Rejected: 	394
# Iteration: 	171 / 1000
# Confirmed: 	11
# Tentative: 	15
# Rejected: 	394
# Iteration: 	172 / 1000
# Confirmed: 	11
# Tentative: 	15
# Rejected: 	394
# Iteration: 	173 / 1000
# Confirmed: 	11
# Tentative: 	15
# Rejected: 	394
# Iteration: 	174 / 1000
# Confirmed: 	11
# Tentative: 	15
# Rejected: 	394
# Iteration: 	175 / 1000
# Confirmed: 	11
# Tentative: 	15
# Rejected: 	394
# Iteration: 	176 / 1000
# Confirmed: 	11
# Tentative: 	15
# Rejected: 	394
# Iteration: 	177 / 1000
# Confirmed: 	11
# Tentative: 	15
# Rejected: 	394
# Iteration: 	178 / 1000
# Confirmed: 	11
# Tentative: 	15
# Rejected: 	394
# Iteration: 	179 / 1000
# Confirmed: 	11
# Tentative: 	15
# Rejected: 	394
# Iteration: 	180 / 1000
# Confirmed: 	11
# Tentative: 	15
# Rejected: 	394
# Iteration: 	181 / 1000
# Confirmed: 	11
# Tentative: 	15
# Rejected: 	394
# Iteration: 	182 / 1000
# Confirmed: 	11
# Tentative: 	15
# Rejected: 	394
# Iteration: 	183 / 1000
# Confirmed: 	11
# Tentative: 	15
# Rejected: 	394
# Iteration: 	184 / 1000
# Confirmed: 	11
# Tentative: 	15
# Rejected: 	394
# Iteration: 	185 / 1000
# Confirmed: 	11
# Tentative: 	15
# Rejected: 	394
# Iteration: 	186 / 1000
# Confirmed: 	11
# Tentative: 	15
# Rejected: 	394
# Iteration: 	187 / 1000
# Confirmed: 	11
# Tentative: 	15
# Rejected: 	394
# Iteration: 	188 / 1000
# Confirmed: 	11
# Tentative: 	15
# Rejected: 	394
# Iteration: 	189 / 1000
# Confirmed: 	12
# Tentative: 	14
# Rejected: 	394
# Iteration: 	190 / 1000
# Confirmed: 	12
# Tentative: 	14
# Rejected: 	394
# Iteration: 	191 / 1000
# Confirmed: 	12
# Tentative: 	14
# Rejected: 	394
# Iteration: 	192 / 1000
# Confirmed: 	12
# Tentative: 	14
# Rejected: 	394
# Iteration: 	193 / 1000
# Confirmed: 	12
# Tentative: 	14
# Rejected: 	394
# Iteration: 	194 / 1000
# Confirmed: 	12
# Tentative: 	14
# Rejected: 	394
# Iteration: 	195 / 1000
# Confirmed: 	12
# Tentative: 	14
# Rejected: 	394
# Iteration: 	196 / 1000
# Confirmed: 	12
# Tentative: 	14
# Rejected: 	394
# Iteration: 	197 / 1000
# Confirmed: 	12
# Tentative: 	14
# Rejected: 	394
# Iteration: 	198 / 1000
# Confirmed: 	12
# Tentative: 	14
# Rejected: 	394
# Iteration: 	199 / 1000
# Confirmed: 	12
# Tentative: 	14
# Rejected: 	394
# Iteration: 	200 / 1000
# Confirmed: 	12
# Tentative: 	14
# Rejected: 	394
# Iteration: 	201 / 1000
# Confirmed: 	12
# Tentative: 	14
# Rejected: 	394
# Iteration: 	202 / 1000
# Confirmed: 	12
# Tentative: 	14
# Rejected: 	394
# Iteration: 	203 / 1000
# Confirmed: 	12
# Tentative: 	14
# Rejected: 	394
# Iteration: 	204 / 1000
# Confirmed: 	12
# Tentative: 	14
# Rejected: 	394
# Iteration: 	205 / 1000
# Confirmed: 	12
# Tentative: 	14
# Rejected: 	394
# Iteration: 	206 / 1000
# Confirmed: 	12
# Tentative: 	14
# Rejected: 	394
# Iteration: 	207 / 1000
# Confirmed: 	12
# Tentative: 	14
# Rejected: 	394
# Iteration: 	208 / 1000
# Confirmed: 	12
# Tentative: 	14
# Rejected: 	394
# Iteration: 	209 / 1000
# Confirmed: 	12
# Tentative: 	14
# Rejected: 	394
# Iteration: 	210 / 1000
# Confirmed: 	12
# Tentative: 	13
# Rejected: 	395
# Iteration: 	211 / 1000
# Confirmed: 	12
# Tentative: 	13
# Rejected: 	395
# Iteration: 	212 / 1000
# Confirmed: 	12
# Tentative: 	13
# Rejected: 	395
# Iteration: 	213 / 1000
# Confirmed: 	12
# Tentative: 	13
# Rejected: 	395
# Iteration: 	214 / 1000
# Confirmed: 	12
# Tentative: 	13
# Rejected: 	395
# Iteration: 	215 / 1000
# Confirmed: 	12
# Tentative: 	13
# Rejected: 	395
# Iteration: 	216 / 1000
# Confirmed: 	12
# Tentative: 	13
# Rejected: 	395
# Iteration: 	217 / 1000
# Confirmed: 	12
# Tentative: 	13
# Rejected: 	395
# Iteration: 	218 / 1000
# Confirmed: 	12
# Tentative: 	13
# Rejected: 	395
# Iteration: 	219 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	220 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	221 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	222 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	223 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	224 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	225 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	226 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	227 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	228 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	229 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	230 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	231 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	232 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	233 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	234 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	235 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	236 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	237 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	238 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	239 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	240 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	241 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	242 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	243 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	244 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	245 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	246 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	247 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	248 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	249 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	250 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	251 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	252 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	253 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	254 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	255 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	256 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	257 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	258 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	259 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	260 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	261 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	262 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	263 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	264 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	265 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	266 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	267 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	268 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	269 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	270 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	271 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	272 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	273 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	274 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	275 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	276 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	277 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	278 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	279 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	280 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	281 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	282 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	283 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	284 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	285 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	286 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	287 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	288 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	289 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	290 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	291 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	292 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	293 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	294 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	295 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	296 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	297 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	298 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	299 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	300 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	301 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	302 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	303 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	304 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	305 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	306 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	307 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	308 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	309 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	310 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	311 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	312 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	313 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	314 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	315 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	316 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	317 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	318 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	319 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	320 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	321 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	322 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	323 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	324 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	325 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	326 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	327 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	328 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	329 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	330 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	331 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	332 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	333 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	334 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	335 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	336 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	337 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	338 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	339 / 1000
# Confirmed: 	13
# Tentative: 	12
# Rejected: 	395
# Iteration: 	340 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	341 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	342 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	343 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	344 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	345 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	346 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	347 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	348 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	349 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	350 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	351 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	352 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	353 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	354 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	355 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	356 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	357 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	358 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	359 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	360 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	361 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	362 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	363 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	364 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	365 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	366 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	367 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	368 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	369 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	370 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	371 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	372 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	373 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	374 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	375 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	376 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	377 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	378 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	379 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	380 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	381 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	382 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	383 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	384 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	385 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	386 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	387 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	388 / 1000
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	396
# Iteration: 	389 / 1000
# Confirmed: 	13
# Tentative: 	10
# Rejected: 	397
# Iteration: 	390 / 1000
# Confirmed: 	13
# Tentative: 	10
# Rejected: 	397
# Iteration: 	391 / 1000
# Confirmed: 	13
# Tentative: 	10
# Rejected: 	397
# Iteration: 	392 / 1000
# Confirmed: 	13
# Tentative: 	10
# Rejected: 	397
# Iteration: 	393 / 1000
# Confirmed: 	13
# Tentative: 	10
# Rejected: 	397
# Iteration: 	394 / 1000
# Confirmed: 	13
# Tentative: 	10
# Rejected: 	397
# Iteration: 	395 / 1000
# Confirmed: 	13
# Tentative: 	10
# Rejected: 	397
# Iteration: 	396 / 1000
# Confirmed: 	13
# Tentative: 	10
# Rejected: 	397
# Iteration: 	397 / 1000
# Confirmed: 	13
# Tentative: 	10
# Rejected: 	397
# Iteration: 	398 / 1000
# Confirmed: 	13
# Tentative: 	10
# Rejected: 	397
# Iteration: 	399 / 1000
# Confirmed: 	13
# Tentative: 	10
# Rejected: 	397
# Iteration: 	400 / 1000
# Confirmed: 	13
# Tentative: 	10
# Rejected: 	397
# Iteration: 	401 / 1000
# Confirmed: 	13
# Tentative: 	10
# Rejected: 	397
# Iteration: 	402 / 1000
# Confirmed: 	13
# Tentative: 	10
# Rejected: 	397
# Iteration: 	403 / 1000
# Confirmed: 	13
# Tentative: 	10
# Rejected: 	397
# Iteration: 	404 / 1000
# Confirmed: 	13
# Tentative: 	10
# Rejected: 	397
# Iteration: 	405 / 1000
# Confirmed: 	13
# Tentative: 	9
# Rejected: 	398
# Iteration: 	406 / 1000
# Confirmed: 	13
# Tentative: 	9
# Rejected: 	398
# Iteration: 	407 / 1000
# Confirmed: 	13
# Tentative: 	9
# Rejected: 	398
# Iteration: 	408 / 1000
# Confirmed: 	13
# Tentative: 	9
# Rejected: 	398
# Iteration: 	409 / 1000
# Confirmed: 	13
# Tentative: 	9
# Rejected: 	398
# Iteration: 	410 / 1000
# Confirmed: 	13
# Tentative: 	9
# Rejected: 	398
# Iteration: 	411 / 1000
# Confirmed: 	13
# Tentative: 	9
# Rejected: 	398
# Iteration: 	412 / 1000
# Confirmed: 	13
# Tentative: 	9
# Rejected: 	398
# Iteration: 	413 / 1000
# Confirmed: 	13
# Tentative: 	9
# Rejected: 	398
# Iteration: 	414 / 1000
# Confirmed: 	13
# Tentative: 	9
# Rejected: 	398
# Iteration: 	415 / 1000
# Confirmed: 	13
# Tentative: 	9
# Rejected: 	398
# Iteration: 	416 / 1000
# Confirmed: 	13
# Tentative: 	9
# Rejected: 	398
# Iteration: 	417 / 1000
# Confirmed: 	13
# Tentative: 	9
# Rejected: 	398
# Iteration: 	418 / 1000
# Confirmed: 	13
# Tentative: 	9
# Rejected: 	398
# Iteration: 	419 / 1000
# Confirmed: 	13
# Tentative: 	9
# Rejected: 	398
# Iteration: 	420 / 1000
# Confirmed: 	13
# Tentative: 	9
# Rejected: 	398
# Iteration: 	421 / 1000
# Confirmed: 	13
# Tentative: 	9
# Rejected: 	398
# Iteration: 	422 / 1000
# Confirmed: 	13
# Tentative: 	9
# Rejected: 	398
# Iteration: 	423 / 1000
# Confirmed: 	13
# Tentative: 	9
# Rejected: 	398
# Iteration: 	424 / 1000
# Confirmed: 	13
# Tentative: 	9
# Rejected: 	398
# Iteration: 	425 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	426 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	427 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	428 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	429 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	430 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	431 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	432 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	433 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	434 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	435 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	436 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	437 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	438 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	439 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	440 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	441 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	442 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	443 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	444 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	445 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	446 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	447 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	448 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	449 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	450 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	451 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	452 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	453 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	454 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	455 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	456 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	457 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	458 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	459 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	460 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	461 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	462 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	463 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	464 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	465 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	466 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	467 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	468 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	469 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	470 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	471 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	472 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	473 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	474 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	475 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	476 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	477 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	478 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	479 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	480 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	481 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	482 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	483 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	484 / 1000
# Confirmed: 	13
# Tentative: 	8
# Rejected: 	399
# Iteration: 	485 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	486 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	487 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	488 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	489 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	490 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	491 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	492 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	493 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	494 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	495 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	496 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	497 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	498 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	499 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	500 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	501 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	502 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	503 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	504 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	505 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	506 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	507 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	508 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	509 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	510 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	511 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	512 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	513 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	514 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	515 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	516 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	517 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	518 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	519 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	520 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	521 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	522 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	523 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	524 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	525 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	526 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	527 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	528 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	529 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	530 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	531 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	532 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	533 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	534 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	535 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	536 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	537 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	538 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	539 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	540 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	541 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	542 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	543 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	544 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	545 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	546 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	547 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	548 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	549 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	550 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	551 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	552 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	553 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	554 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	555 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	556 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	557 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	558 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	559 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	560 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	561 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	562 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	563 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	564 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	565 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	566 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	567 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	568 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	569 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	570 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	571 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	572 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	573 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	574 / 1000
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	399
# Iteration: 	575 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	576 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	577 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	578 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	579 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	580 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	581 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	582 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	583 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	584 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	585 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	586 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	587 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	588 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	589 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	590 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	591 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	592 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	593 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	594 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	595 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	596 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	597 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	598 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	599 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	600 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	601 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	602 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	603 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	604 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	605 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	606 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	607 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	608 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	609 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	610 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	611 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	612 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	613 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	614 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	615 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	616 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	617 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	618 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	619 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	620 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	621 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	622 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	623 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	624 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	625 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	626 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	627 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	628 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	629 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	630 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	631 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	632 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	633 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	634 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	635 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	636 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	637 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	638 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	639 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	640 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	641 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	642 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	643 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	644 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	645 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	646 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	647 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	648 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	649 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	650 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	651 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	652 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	653 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	654 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	655 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	656 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	657 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	658 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	659 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	660 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	661 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	662 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	663 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	664 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	665 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	666 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	667 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	668 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	669 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	670 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	671 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	672 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	673 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	674 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	675 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	676 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	677 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	678 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	679 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	680 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	681 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	682 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	683 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	684 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	685 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	686 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	687 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	688 / 1000
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	399
# Iteration: 	689 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	690 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	691 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	692 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	693 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	694 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	695 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	696 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	697 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	698 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	699 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	700 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	701 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	702 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	703 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	704 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	705 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	706 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	707 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	708 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	709 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	710 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	711 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	712 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	713 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	714 / 1000
# ...
# Rejected: 	400
# Iteration: 	763 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	764 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	765 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	766 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	767 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	768 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	769 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	770 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	771 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	772 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	773 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	774 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	775 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	776 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	777 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	778 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	779 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	780 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	781 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	782 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	783 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	784 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	785 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	786 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	787 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	788 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	789 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	790 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	791 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	792 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	793 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	794 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	795 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	796 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	797 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	798 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	799 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	800 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	801 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	802 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	803 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	804 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	805 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	806 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	807 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	808 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	809 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	810 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	811 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	812 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	813 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	814 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	815 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	816 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	817 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	818 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	819 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	820 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	821 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	822 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	823 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	824 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	825 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	826 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	827 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	828 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	829 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	830 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	831 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	832 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	833 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	834 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	835 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	836 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	837 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	838 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	839 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	840 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	841 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	842 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	843 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	844 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	845 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	846 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	847 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	848 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	849 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	850 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	851 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	852 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	853 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	854 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	855 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	856 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	857 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	858 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	859 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	860 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	861 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	862 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	863 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	864 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	865 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	866 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	867 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	868 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	869 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	870 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	871 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	872 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	873 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	874 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	875 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	876 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	877 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	878 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	879 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	880 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	881 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	882 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	883 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	884 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	885 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	886 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	887 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	888 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	889 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	890 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	891 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	892 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	893 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	894 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	895 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	896 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	897 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	898 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	899 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	900 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	901 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	902 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	903 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	904 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	905 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	906 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	907 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	908 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	909 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	910 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	911 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	912 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	913 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	914 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	915 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	916 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	917 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	918 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	919 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	920 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	921 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	922 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	923 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	924 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	925 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	926 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	927 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	928 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	929 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	930 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	931 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	932 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	933 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	934 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	935 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	936 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	937 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	938 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	939 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	940 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	941 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	942 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	943 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	944 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	945 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	946 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	947 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	948 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	949 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	950 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	951 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	952 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	953 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	954 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	955 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	956 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	957 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	958 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	959 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	960 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	961 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	962 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	963 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	964 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	965 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	966 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	967 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	968 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	969 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	970 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	971 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	972 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	973 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	974 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	975 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	976 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	977 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	978 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	979 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	980 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	981 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	982 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	983 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	984 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	985 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	986 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	987 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	988 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	989 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	990 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	991 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	992 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	993 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	994 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	995 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	996 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	997 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	998 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
# Iteration: 	999 / 1000
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	400
#
#
# BorutaPy finished running.
#
# Iteration: 	1000 / 1000
# Confirmed: 	15
# Tentative: 	4
# Rejected: 	401

# %% [markdown]
# ## Protein Coding gene selected using boruta

# %%
selected_features_pc
# Out:
# ['ENSG00000158711',
#  'ENSG00000121481',
#  'ENSG00000284770',
#  'ENSG00000117395',
#  'ENSG00000117593',
#  'ENSG00000188290',
#  'ENSG00000171824',
#  'ENSG00000117266',
#  'ENSG00000271425',
#  'ENSG00000007923',
#  'ENSG00000180667',
#  'ENSG00000171793',
#  'ENSG00000160818',
#  'ENSG00000143952',
#  'ENSG00000155744',
#  'ENSG00000091409',
#  'ENSG00000115762',
#  'ENSG00000115457',
#  'ENSG00000116106',
#  'ENSG00000115760',
#  'ENSG00000119787',
#  'ENSG00000163655',
#  'ENSG00000034533',
#  'ENSG00000144713',
#  'ENSG00000197548',
#  'ENSG00000176945',
#  'ENSG00000145241',
#  'ENSG00000138764',
#  'ENSG00000164104',
#  'ENSG00000178988',
#  'ENSG00000185477',
#  'ENSG00000109133',
#  'ENSG00000150712',
#  'ENSG00000168944',
#  'ENSG00000152942',
#  'ENSG00000145741',
#  'ENSG00000197451',
#  'ENSG00000113048',
#  'ENSG00000145996',
#  'ENSG00000135334',
#  'ENSG00000274641',
#  'ENSG00000137312',
#  'ENSG00000272325',
#  'ENSG00000010810',
#  'ENSG00000136231',
#  'ENSG00000164713',
#  'ENSG00000135164',
#  'ENSG00000160993',
#  'ENSG00000106591',
#  'ENSG00000179144',
#  'ENSG00000169188',
#  'ENSG00000198689',
#  'ENSG00000189369',
#  'ENSG00000198205',
#  'ENSG00000023287',
#  'ENSG00000197265',
#  'ENSG00000155096',
#  'ENSG00000213619',
#  'ENSG00000110075',
#  'ENSG00000149541',
#  'ENSG00000070081',
#  'ENSG00000151500',
#  'ENSG00000166181',
#  'ENSG00000135387',
#  'ENSG00000165512',
#  'ENSG00000168209',
#  'ENSG00000170312',
#  'ENSG00000166024',
#  'ENSG00000133704',
#  'ENSG00000111144',
#  'ENSG00000111237',
#  'ENSG00000150977',
#  'ENSG00000059804',
#  'ENSG00000130177',
#  'ENSG00000151332',
#  'ENSG00000100442',
#  'ENSG00000168282',
#  'ENSG00000117899',
#  'ENSG00000182774',
#  'ENSG00000088682',
#  'ENSG00000182885',
#  'ENSG00000159720',
#  'ENSG00000167207',
#  'ENSG00000140941',
#  'ENSG00000159593',
#  'ENSG00000108961',
#  'ENSG00000161970',
#  'ENSG00000006744',
#  'ENSG00000108298',
#  'ENSG00000141526',
#  'ENSG00000125691',
#  'ENSG00000101752',
#  'ENSG00000152240',
#  'ENSG00000101474',
#  'ENSG00000101442',
#  'ENSG00000132664',
#  'ENSG00000125912',
#  'ENSG00000130307',
#  'ENSG00000269858',
#  'ENSG00000197405',
#  'ENSG00000167565',
#  'ENSG00000197951',
#  'ENSG00000187266',
#  'ENSG00000160570',
#  'ENSG00000125743',
#  'ENSG00000130255',
#  'ENSG00000186431',
#  'ENSG00000172081',
#  'ENSG00000067048',
#  'ENSG00000100284',
#  'ENSG00000128191',
#  'ENSG00000154734',
#  'ENSG00000183255',
#  'ENSG00000142192']

# %% [markdown]
# ## Lncrna Selected using boruta

# %%
selected_features_ln
# Out:
# ['ENSG00000228606',
#  'ENSG00000272449',
#  'ENSG00000272145',
#  'ENSG00000290041',
#  'ENSG00000225649',
#  'ENSG00000288836',
#  'ENSG00000291124',
#  'ENSG00000290871',
#  'ENSG00000226530',
#  'ENSG00000289316',
#  'ENSG00000291048',
#  'ENSG00000224307',
#  'ENSG00000221817',
#  'ENSG00000256039',
#  'ENSG00000247774',
#  'ENSG00000235532',
#  'ENSG00000289083',
#  'ENSG00000275888',
#  'ENSG00000277089',
#  'ENSG00000268573',
#  'ENSG00000291067',
#  'ENSG00000288719']

# %% [markdown]
# ## Pseduogene selected using boruta

# %%
selected_features_ps
# Out:
# ['ENSG00000234851',
#  'ENSG00000230409',
#  'ENSG00000132967',
#  'ENSG00000246596',
#  'ENSG00000217527',
#  'ENSG00000218809',
#  'ENSG00000183444',
#  'ENSG00000165178',
#  'ENSG00000236567',
#  'ENSG00000244398',
#  'ENSG00000258352',
#  'ENSG00000240342',
#  'ENSG00000232587',
#  'ENSG00000223959',
#  'ENSG00000214425']

# %%
protein_coding = PostProcessing(protein_coding,selected_features_pc)

# %%
protein_coding
# Out:
#             Sample_ID category ENSG00000158711 ENSG00000121481  \
# 0    IGIB113000849750     mild        7.383388        5.365834
# 1    IGIB113001484596     mild        5.864997        4.427129
# 2    IGIB113002156413     mild        7.786278        5.856009
# 3    IGIB113002224539     mild        6.577487        5.201215
# 4    IGIB113002257842     mild        7.866947        5.741448
# ..                ...      ...             ...             ...
# 107    IGIB1130581789   severe        7.185213        6.576621
# 108    IGIB1130630558   severe        6.593348        7.863512
# 109    IGIB1130925327   severe        6.994577          6.0972
# 110    IGIB1130927408   severe        6.087678          5.7225
# 111     IGIB113093534   severe         7.09797        2.897784
#
#     ENSG00000284770 ENSG00000117395 ENSG00000117593 ENSG00000188290  \
# 0          4.346439        4.421764        3.722133        7.501281
# 1          5.189263        4.166348        4.630951        7.919929
# 2          4.763183        4.789456        4.004076        7.238069
# 3          4.815029        4.186434        3.956746        8.052248
# 4          4.264734        4.231073        5.174939        4.852259
# ..              ...             ...             ...             ...
# 107        5.295892        6.023768        4.585234        5.989932
# 108        6.924312        6.472316        7.128248        5.787384
# 109        4.621329        5.107753        4.685862        3.537951
# 110        5.172901        5.385487        4.979868        6.346178
# 111        2.872278        6.384008        2.811554        6.501433
#
#     ENSG00000171824 ENSG00000117266  ... ENSG00000125743 ENSG00000130255  \
# 0          5.716382        4.130014  ...        5.731206        8.364853
# 1          5.761629         5.45363  ...        5.440821        7.572712
# 2          6.386381        4.338986  ...        6.238875        8.320083
# 3          5.298212        4.523816  ...        5.757348        8.338068
# 4           4.97545        3.152815  ...        5.701162        8.403633
# ..              ...             ...  ...             ...             ...
# 107        7.410619        3.282507  ...        7.382007        9.743063
# 108        6.694107        2.918514  ...        7.349402        9.574144
# 109        7.284443        4.640069  ...          7.6996        9.839856
# 110        6.702339        3.784988  ...         6.61148        8.721974
# 111        2.818554        2.918514  ...        7.540919        9.335217
#
#     ENSG00000186431 ENSG00000172081 ENSG00000067048 ENSG00000100284  \
# 0           9.72584        9.705569        8.223652        9.468817
# 1         10.737821       10.050547        8.565993        9.835887
# 2          9.426954        9.009914        9.096065        9.170082
# 3         10.805577        9.940364        3.322247       10.559174
# 4         10.242025       11.019502        4.483703        9.271521
# ..              ...             ...             ...             ...
# 107        9.419201        8.595733        9.759901        9.307612
# 108        8.624466        7.684762        9.976802        9.004018
# 109        9.104871        7.757686       10.708712        8.675682
# 110        9.869153        8.521139        3.374427         8.99342
# 111        8.521019        8.983236       10.974514        8.765922
#
#     ENSG00000128191 ENSG00000154734 ENSG00000183255 ENSG00000142192
# 0          5.261334        4.058145        9.532755        7.213095
# 1          5.833667        5.257737        9.179533        6.916128
# 2          4.782876        3.821914        9.008836        7.456846
# 3          5.705938        3.647087        9.854809        7.524495
# 4          4.967891        4.620415        9.000816        8.097238
# ..              ...             ...             ...             ...
# 107        5.217771        3.112073        9.183453        9.442274
# 108        6.189227         3.02625        9.156831        8.507146
# 109        5.800424        4.621882        9.050459        6.548125
# 110        6.614055         3.02625        8.412335         8.13854
# 111         6.08263         3.02625        7.337409         8.24413
#
# [112 rows x 116 columns]

# %%
lncrna = PostProcessing(lncrna,selected_features_ln)

# %%
lncrna
# Out:
#             Sample_ID category ENSG00000228606 ENSG00000272449  \
# 0    IGIB113000849750     mild        3.393696        5.176199
# 1    IGIB113001484596     mild        3.756077        6.227766
# 2    IGIB113002156413     mild         3.09661        4.364346
# 3    IGIB113002224539     mild        3.910101        6.109291
# 4    IGIB113002257842     mild        4.110453        7.016891
# ..                ...      ...             ...             ...
# 107    IGIB1130581789   severe        4.640736        4.336248
# 108    IGIB1130630558   severe         6.73094        2.854354
# 109    IGIB1130925327   severe         3.27409        5.442974
# 110    IGIB1130927408   severe        3.999571        4.540051
# 111     IGIB113093534   severe        2.570186        2.854354
#
#     ENSG00000272145 ENSG00000290041 ENSG00000225649 ENSG00000288836  \
# 0          3.116306        4.736968        3.823076        3.989919
# 1          4.586185        5.410261        5.745809        4.102743
# 2          4.196103        3.631024        3.607765        4.252817
# 3          4.526445        4.043277        4.191049        3.881226
# 4          4.592232        6.528928          4.3661        2.913833
# ..              ...             ...             ...             ...
# 107        4.766741        3.871263        2.686007        5.552801
# 108        5.507822        2.564716        3.216121        2.686671
# 109        5.114919        3.733103         5.20076        4.473268
# 110        4.729027        3.778355        3.216121        5.535608
# 111        2.710026        2.564716        3.216121        6.142584
#
#     ENSG00000291124 ENSG00000290871  ... ENSG00000221817 ENSG00000256039  \
# 0          4.402871        7.081518  ...        3.922318        3.366907
# 1          4.768421        7.075495  ...        6.231755        5.016794
# 2           4.69512        6.744937  ...        4.490518        3.789645
# 3          4.978112        6.000902  ...        5.425319        3.776143
# 4          5.808553        6.968498  ...        4.715154        4.318313
# ..              ...             ...  ...             ...             ...
# 107        6.337066        8.155131  ...        5.905209        6.253349
# 108         2.79161        8.306954  ...        2.964446        5.163178
# 109        7.025807        6.315134  ...        5.432468        7.061169
# 110        5.276017        8.249071  ...        5.591428        5.652732
# 111        7.643075        7.265267  ...        6.439898        5.780104
#
#     ENSG00000247774 ENSG00000235532 ENSG00000289083 ENSG00000275888  \
# 0          5.586906        3.342666        4.138615        6.739795
# 1          5.443252        4.634843        3.920713        6.558285
# 2          5.682987        3.158193        3.947941        5.158623
# 3          4.926535        3.473027        5.081995        6.444782
# 4          5.783158        2.570834        3.445897        7.765539
# ..              ...             ...             ...             ...
# 107         7.59608        3.903799        4.811756        5.831799
# 108        7.200411        2.968194        2.950556        7.548168
# 109        6.293421        5.374744        5.020138        3.502451
# 110        7.154189        4.196861        5.227971        6.657245
# 111        7.205997        2.968194        2.950556        5.779759
#
#     ENSG00000277089 ENSG00000268573 ENSG00000291067 ENSG00000288719
# 0          3.214431        3.846309        7.780436        3.903799
# 1          4.132329        3.814242        7.302165        3.580753
# 2          3.426264        3.523964        7.423283        3.759353
# 3          3.765713        4.308316        7.313628        4.321124
# 4           2.36657        3.341752        7.161449        3.807219
# ..              ...             ...             ...             ...
# 107        4.259842        4.839456         6.24166        3.800383
# 108        7.392611        5.528292        6.703615        5.556268
# 109        2.973952        4.143962        7.008267         4.37202
# 110         4.79379        5.011791        6.870311        5.612968
# 111        2.973952        6.188938        7.212969          7.0893
#
# [112 rows x 24 columns]

# %%
pseudogene = PostProcessing(pseudogene,selected_features_ps)

# %%
pseudogene
# Out:
#             Sample_ID category ENSG00000234851 ENSG00000230409  \
# 0    IGIB113000849750     mild        7.767143        4.415993
# 1    IGIB113001484596     mild        7.808965        3.788586
# 2    IGIB113002156413     mild        7.982593        4.335493
# 3    IGIB113002224539     mild        7.619297        4.669483
# 4    IGIB113002257842     mild        8.221667        3.463011
# ..                ...      ...             ...             ...
# 107    IGIB1130581789   severe       10.151376        4.866351
# 108    IGIB1130630558   severe        9.047081        2.912609
# 109    IGIB1130925327   severe        9.727064        2.912609
# 110    IGIB1130927408   severe         8.55867        5.590852
# 111     IGIB113093534   severe        9.300981        2.912609
#
#     ENSG00000132967 ENSG00000246596 ENSG00000217527 ENSG00000218809  \
# 0          6.376321        3.693547        4.013369        5.657341
# 1           4.34909        4.063922        4.300458        4.744479
# 2          5.679668        3.785966        3.701473         4.99343
# 3          5.548975        3.532907        4.308827         4.66396
# 4          5.428075          3.1445         5.11465        5.027389
# ..              ...             ...             ...             ...
# 107        7.341479         4.85197         3.68286        4.315888
# 108        2.643622        6.340482        2.696228         5.40824
# 109        5.935803        4.529058        2.696228        2.644806
# 110        7.261906        4.760709        2.696228        2.644806
# 111        8.977263        2.740606        2.696228        2.644806
#
#     ENSG00000183444 ENSG00000165178 ENSG00000236567 ENSG00000244398  \
# 0           3.90157       10.403825        4.007397        6.155713
# 1          4.351585        9.251843        2.867436        7.525433
# 2          4.219661       10.351828        3.928359        6.813189
# 3          2.616095        9.820147         3.74556        6.601214
# 4          4.303364        8.435416        5.821256        6.927659
# ..              ...             ...             ...             ...
# 107        3.322302         8.71856        3.514838        8.983962
# 108        3.137626        7.202627        2.672986        8.444658
# 109        3.137626        7.145122        2.672986        6.303316
# 110        3.137626        9.225709        2.672986        6.827294
# 111        3.137626        7.991879        2.672986        8.838029
#
#     ENSG00000258352 ENSG00000240342 ENSG00000232587 ENSG00000223959  \
# 0          3.711438        7.329952        4.461518        4.838655
# 1          2.753481        6.350414        4.157192        4.505077
# 2          3.243649        7.159495        4.587518        5.201479
# 3          2.774072        6.431403        3.455814        4.824798
# 4           2.55311        7.886205        4.946954         4.18887
# ..              ...             ...             ...             ...
# 107        3.429047        6.857262        4.655313        5.750594
# 108         2.71856        8.604207        2.861471        6.566482
# 109        4.097497         8.57973        4.798286        6.305203
# 110        3.835376        8.094254        4.548323        5.202253
# 111         2.71856        7.211934        2.861471        2.784041
#
#     ENSG00000214425
# 0          5.195427
# 1          4.041947
# 2          5.665678
# 3          2.691084
# 4          4.971547
# ..              ...
# 107          6.6748
# 108        2.729751
# 109         5.87925
# 110        5.738415
# 111        7.066533
#
# [112 rows x 17 columns]

# %%
def train_and_evaluate_model(best_rf,df,name, n_iter=10 ,test_size=0.15):
    X = df.drop(['Sample_ID', 'category'], axis=1)
    y = df['category']
    
    # Split the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=42)
    best_rf.fit(X_train, y_train)
    y_test_bin = label_binarize(y_test, classes=best_rf.classes_)
    classifier = OneVsRestClassifier(best_rf)
    y_score = classifier.fit(X_train, y_train).predict_proba(X_test)
    y_pred = classifier.predict(X_test)
    
    # Make predictions on the test set
   
    
    # Calculate accuracy
    accuracy = accuracy_score(y_test, y_pred)
    
    
# Plot the SHAP stacked bar plot for all classes
    #shap.summary_plot(shap_values_stacked, X_test, feature_names=X.columns, plot_type="bar", class_names=["Mild", "Moderate", "Severe"])

    plt.show()


    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(len(best_rf.classes_)):
        fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_score[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curve for each class
    plt.figure(dpi = 600,figsize=(8, 5))
    colors = ['#68B984', '#FFC93C', '#6499E9']  # Add more colors if needed
    class_labels = best_rf.classes_

    for i, color, label in zip(range(len(class_labels)), colors, class_labels):
        plt.plot(fpr[i], tpr[i], color=color, lw=2, label=f'{label} (AUC = {roc_auc[i]:.2f})')

    plt.plot([0, 1], [0, 1], 'k--', lw=2)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(name)
    plt.legend(loc="lower right")
    #plt.savefig(name + '_auroc_plot.svg')
    plt.show()
    

    return X_test,best_rf

# %%
X_test_pc,best_rf_model_pc = train_and_evaluate_model(best_rf_pc,protein_coding, 'Protein Coding',n_iter=5, test_size=0.20)

# %%
X_test_ln,best_rf_model_ln = train_and_evaluate_model(best_rf_ln,lncrna, 'LncRNA',n_iter=5, test_size=0.20)

# %%
X_test_ps,best_rf_model_ps = train_and_evaluate_model(best_rf_ps,pseudogene, 'PSeudogene',n_iter=5, test_size=0.20)

# %%
X_test_all,best_rf_model_all = train_and_evaluate_model(best_rf_all,all_data_sel, 'All Data',n_iter=5, test_size=0.20)

# %%
## Shap -- > A model interpretability so that we can know the exact impact

# %%
import shap
import seaborn as sns
from matplotlib.colors import ListedColormap
def shapleyplot(model, X_test_data, name):
    colors = ['#68B984', '#FFC93C', '#6499E9']
    cmap = ListedColormap(colors)
    
    explainer = shap.TreeExplainer(model)
    shap_values = explainer.shap_values(X_test_data)
    
    plt.figure(dpi=600, figsize=(15, 5))
    shap.summary_plot(shap_values, X_test_data, max_display=120, class_names=['mild', 'moderate', 'severe'], color=cmap, show=False)
    #plt.savefig(name + '_shapplot.svg')
    return shap_values

# %%
shap_pseudo = shapleyplot(best_rf_model_all,X_test_all, 'All Data')

# %%
shap_pc = shapleyplot(best_rf_model_pc,X_test_pc, 'Protein Coding')

# %%
shap_ln = shapleyplot(best_rf_model_ln,X_test_ln, 'LncRNA')

# %%
shap_ps = shapleyplot(best_rf_model_ps,X_test_ps, 'Pseudogene')
